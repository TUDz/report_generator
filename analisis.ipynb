# %%
import numpy as np
import pandas as pd

# %%
# Carga de archivos
demograficos = pd.read_csv('./DM_DatosGenerales.txt', delimiter='|', encoding='latin1', header=0, dtype=object)
dispersiones = pd.read_csv('./DM_DatosDispersion.txt', delimiter='|', encoding='latin1', header=0, dtype=object)
domicilios = pd.read_csv('./DM_DatosDomicilio.txt', delimiter='|', encoding='latin1', header=0, dtype=object)
marca_big = pd.read_csv('./Marca_BIG.txt', delimiter='|', encoding='latin1', header=0, dtype=object)

# %%
demograficos
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 0                     4673      236644         1          1          4003
# 1                     4673      236645         1          1          2749
# 2                     4673      236648         1          1          3654
# 3                     4673      236656         1          1          2781
# 4                     4673      236659         1          1          5128
# ...                    ...         ...       ...        ...           ...
# 2223545               6626     2163353         1          1          5306
# 2223546               5383     2130648         1          1          6729
# 2223547               5383     2156178         1          9          8681
# 2223548               5383     2132523         1         39          4727
# 2223549               5983     2158180         1          1          6774
#
#         FI_FOLIOCU                  FC_INSTITUCION  \
# 0            13916                IMSS PENSIONADOS
# 1            33898                IMSS PENSIONADOS
# 2            34850                IMSS PENSIONADOS
# 3            33562                IMSS PENSIONADOS
# 4            18979                IMSS PENSIONADOS
# ...            ...                             ...
# 2223545       4881        INTIMARK S DE R L DE C V
# 2223546     103016         BAZ PORTABILIDAD NOMINA
# 2223547      15624         BAZ PORTABILIDAD NOMINA
# 2223548       2946         BAZ PORTABILIDAD NOMINA
# 2223549      72966  LIDERES EN INNOVACION SA DE CV
#
#                            FC_NOMBRECOMPLETO   FD_FECHANACIMIENTO  \
# 0          GUILLERMO DAGOBERTO NAVA GONZALEZ  11/01/1921 00:00:00
# 1        GUILLERMO FEDERICO MARTINEZ CABRERA  07/21/1945 00:00:00
# 2              GUILLERMO HECTOR SOTO CABAÑAS  06/25/1944 00:00:00
# 3               HECTOR JOSE GUZMAN GUTIERREZ  12/18/1949 00:00:00
# 4             HECTOR JULIO NAVARRO GUTIERREZ  07/14/1944 00:00:00
# ...                                      ...                  ...
# 2223545         MACARIO HERMENEGILDO SEGUNDO  04/25/1975 00:00:00
# 2223546              RAQUEL MENDIOLA GALINDO  08/01/1961 00:00:00
# 2223547            LUIS IGNACIO ZUMAYA MERAZ  10/19/2001 00:00:00
# 2223548            JOSE CRISANTOS SOTO CASAS  05/26/1994 00:00:00
# 2223549            MIGUEL ANGEL NAVA CABELLO  07/19/1997 00:00:00
#
#         FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO FC_APELLIDO_MATERNO  \
# 0                  MEXICO  ...                NAVA            GONZALEZ
# 1                  MEXICO  ...            MARTINEZ             CABRERA
# 2                  MEXICO  ...                SOTO             CABAÑAS
# 3                  MEXICO  ...              GUZMAN           GUTIERREZ
# 4                  MEXICO  ...             NAVARRO           GUTIERREZ
# ...                   ...  ...                 ...                 ...
# 2223545               NaN  ...        HERMENEGILDO             SEGUNDO
# 2223546               NaN  ...            MENDIOLA             GALINDO
# 2223547               NaN  ...              ZUMAYA               MERAZ
# 2223548               NaN  ...                SOTO               CASAS
# 2223549               NaN  ...                NAVA             CABELLO
#
#         FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO  \
# 0                1  09/14/2007 00:00:00                1              19
# 1                1  03/28/2018 00:00:00                1              28
# 2                1  05/19/2012 00:00:00                1              15
# 3                1  06/13/2011 00:00:00                1              14
# 4                1  05/15/2007 00:00:00                1              26
# ...            ...                  ...              ...             ...
# 2223545          1                  NaN                1              15
# 2223546          1  02/15/2021 17:48:58                1              11
# 2223547          1  02/25/2021 17:58:32                1              24
# 2223548          1  02/17/2021 17:04:40                1              14
# 2223549          1                  NaN                1              17
#
#         FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 0                   2             7      2            484
# 1                   4             7      2            484
# 2                   2             7      2            484
# 3                   2             7      2            484
# 4                   2             7      2            484
# ...               ...           ...    ...            ...
# 2223545             0             7      2            484
# 2223546             1             7      1            484
# 2223547             0             7      2            484
# 2223548             0             7      2            484
# 2223549             2             7      2            484
#
# [2223550 rows x 42 columns]

# %%
dispersiones['FN_SALARIO'] = dispersiones['FN_SALARIO'].astype(float)

# %%
dispersiones['FIPERIODICIDADPAGO'] = pd.to_numeric(dispersiones['FIPERIODICIDADPAGO'], errors='coerce')

# %%
dispersiones = dispersiones.dropna(subset=['FIPERIODICIDADPAGO'])

# %%
dispersiones = dispersiones.dropna(subset=['FI_TOTALDISPER'])

# %%
dispersiones['FIPERIODICIDADPAGO'] = dispersiones['FIPERIODICIDADPAGO'].astype(int)

# %%
dispersiones['FI_TOTALDISPER'] = dispersiones['FI_TOTALDISPER'].astype(int)

# %%
dispersiones = dispersiones[dispersiones['FN_SALARIO'] > 0]

# %%
dispersiones['FIPERIODICIDADPAGO'] = dispersiones['FIPERIODICIDADPAGO'].astype(int)

# %%
dispersiones
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO             FC_CUENTA  \
# 2                     4673      242209  01272132910106618084
# 5                     4673      242244  01271850800109297939
# 7                     4673      242257  01275002930180288218
# 8                     4673      242258  01270518230186223129
# 11                    4673      242267  01270185550110359915
# ...                    ...         ...                   ...
# 2226012               5383     2770286  01274297230161104028
# 2226013               5383     2681052  01270148160159598051
# 2226015               4673     2755816  01276318600126183128
# 2226016               4673     2756309  01272396861376542099
# 2226017               5383     2765944  01276923210161006636
#
#              FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 2        11/30/2021 00:00:00               7    19099.48             MENSUAL
# 5        11/30/2021 00:00:00               7     9738.18             MENSUAL
# 7        11/30/2021 00:00:00               7     2324.67             MENSUAL
# 8        11/30/2021 00:00:00               7     2982.38             MENSUAL
# 11       11/30/2021 00:00:00               7     7668.34             MENSUAL
# ...                      ...             ...         ...                 ...
# 2226012  12/14/2021 00:00:00              13     2913.41           QUINCENAL
# 2226013  12/13/2021 00:00:00              18      472.08             SEMANAL
# 2226015  11/30/2021 00:00:00               4     5780.85             MENSUAL
# 2226016  11/30/2021 00:00:00               4     5581.51             MENSUAL
# 2226017  12/10/2021 00:00:00              14     1293.96             SEMANAL
#
#         FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 2                    NaN            PENSIONADOS Y JUBILADOS             11
# 5                    NaN            PENSIONADOS Y JUBILADOS             11
# 7                    NaN            PENSIONADOS Y JUBILADOS             11
# 8                    NaN            PENSIONADOS Y JUBILADOS             11
# 11                   NaN            PENSIONADOS Y JUBILADOS             11
# ...                  ...                                ...            ...
# 2226012              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 2226013              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 2226015              NaN            PENSIONADOS Y JUBILADOS             11
# 2226016              NaN            PENSIONADOS Y JUBILADOS             11
# 2226017              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
#
#         FI_CREDITOSACTIV  FIPERIODICIDADPAGO FI_CTA_DIGITOS
# 2                      0                   3      106618084
# 5                      2                   3      109297939
# 7                      0                   3      180288218
# 8                      0                   3      186223129
# 11                     0                   3      110359915
# ...                  ...                 ...            ...
# 2226012                0                   2      161104028
# 2226013                0                   1      159598051
# 2226015                0                   3      126183128
# 2226016                0                   3     1376542099
# 2226017                1                   1      161006636
#
# [618624 rows x 13 columns]

# %%
empleados_muestra = dispersiones.sample(n=100000)

# %%
domicilios = domicilios.dropna(subset=['FC_LATITUD'])

# %%
domicilios = domicilios.dropna(subset=['FC_ID_ESTADO'])

# %%
domicilios = domicilios.dropna(subset=['FI_ID_MUNICIPIO'])

# %%
domicilios
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO       FC_CALLEHOGAR FC_NUMEXTHOGAR  \
# 0                     4673      241071     CAMINO AL CAMPO             SN
# 1                     4673      235656           ESMERALDA            110
# 2                     4673      235657   SANTIAGO DEL ESTE            305
# 3                     4673      235658  GUADALUPE VICTORIA              1
# 4                     4673      235659              HUAMAC           8017
# ...                    ...         ...                 ...            ...
# 2223368              11055     2764501    C SIN NOMBRE S/N          00000
# 2223369               5383     2752786   AV ALVARO OBREGON              3
# 2223370               5383     2775670        SANTA ROSALA           1135
# 2223371               4673     2756257               NARDO            104
# 2223377               5383     2681182       PRIV LOTUS 10             10
#
#         FC_NUMINTHOGAR               FC_COLONIAHOGAR  \
# 0                   SN      AMPLIACION PLAN DE AYALA
# 1                  NaN                    CUAUHTEMOC
# 2                  305                VILLAS DEL SUR
# 3                    1                       TEOCELO
# 4                 8017              LOMAS DE CUMBRES
# ...                ...                           ...
# 2223368            NaN  Centro Cruz de Elota Sinaloa
# 2223369            NaN              Vicente Guerrero
# 2223370            NaN                   SANTA MARIA
# 2223371            NaN        SANTA JULIA AMPLIACION
# 2223377            NaN                    El Cerrito
#
#                 FC_MUNICIPIOHOGAR FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS  \
# 0                         CUAUTLA        MORELOS           62740  MEXICO
# 1        SAN NICOLAS DE LOS GARZA     NUEVO LEON           66450  MEXICO
# 2                       QUERETARO      QUERETARO           76148  MEXICO
# 3                         TEOCELO       VERACRUZ           91615  MEXICO
# 4                       MONTERREY     NUEVO LEON           64140  MEXICO
# ...                           ...            ...             ...     ...
# 2223368                     ELOTA        SINALOA           82700  MEXICO
# 2223369                  Delicias      CHIHUAHUA           33100  MEXICO
# 2223370               GUADALAJARA        JALISCO           44350  Mexico
# 2223371           PACHUCA DE SOTO        HIDALGO           42080  Mexico
# 2223377              Huauchinango         PUEBLA           73160  MEXICO
#
#         FI_ID_TIPOVIVIENDA FC_ID_TIPOVIVIENDA           FC_LATITUD  \
# 0                        3             PROPIA  18.7917820000000000
# 1                        3             PROPIA  25.7328120000000000
# 2                        3             PROPIA  20.6549980000000000
# 3                        3             PROPIA  19.3860900000000000
# 4                        3             PROPIA  25.7375740000000000
# ...                    ...                ...                  ...
# 2223368                  3             PROPIA  23.9317920000000000
# 2223369                  3             PROPIA  28.1982830000000000
# 2223370                  3             PROPIA  20.6873130000000000
# 2223371                  3             PROPIA  20.1105960000000000
# 2223377                  3             PROPIA  20.1555560000000000
#
#                    FC_LONGITUD FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO  \
# 0         -98.9010970000000000         NaN           NaN               6
# 1        -100.2946250000000000         NaN             2              46
# 2        -100.3938090000000000         NaN           NaN              14
# 3         -96.9746210000000000         NaN             1             164
# 4        -100.3584220000000000         NaN           NaN              39
# ...                        ...         ...           ...             ...
# 2223368  -106.8830300000000000         NaN           NaN               8
# 2223369  -105.4286970000000000         NaN           NaN              21
# 2223370  -103.3135330000000000         NaN             5              39
# 2223371   -98.7668020000000000         NaN            10              48
# 2223377   -98.0343770000000000         NaN            25              71
#
#         FC_ID_ESTADO FI_ID_PAIS
# 0                 17          1
# 1                 19          1
# 2                 22          1
# 3                 30          1
# 4                 19          1
# ...              ...        ...
# 2223368           25          1
# 2223369            8          1
# 2223370           14          1
# 2223371           13          1
# 2223377           21          1
#
# [1059945 rows x 19 columns]

# %%
domicilios = domicilios.dropna(subset=['FI_ID_COLONIA'])

# %%
domicilios
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO          FC_CALLEHOGAR FC_NUMEXTHOGAR  \
# 1                     4673      235656              ESMERALDA            110
# 3                     4673      235658     GUADALUPE VICTORIA              1
# 7                     4673      235665           64 X 41 Y 43           365B
# 9                     4673      235669              DR BALMIS             24
# 10                    4673      242188            EX CAROLINA             SN
# ...                    ...         ...                    ...            ...
# 2223365              11055     2764482            AD PROVENIR              9
# 2223366              11055     2764496  ROBERTO GARCIA BARRON           1946
# 2223370               5383     2775670           SANTA ROSALA           1135
# 2223371               4673     2756257                  NARDO            104
# 2223377               5383     2681182          PRIV LOTUS 10             10
#
#         FC_NUMINTHOGAR         FC_COLONIAHOGAR         FC_MUNICIPIOHOGAR  \
# 1                  NaN              CUAUHTEMOC  SAN NICOLAS DE LOS GARZA
# 3                    1                 TEOCELO                   TEOCELO
# 7                 365B           MERIDA CENTRO                    MERIDA
# 9                   24                DOCTORES                CUAUHTEMOC
# 10                  SN                  CENTRO              COSAMALOAPAN
# ...                ...                     ...                       ...
# 2223365              9        FRACC. EL RETIRO      SANTA MARIA DEL TULE
# 2223366            NaN              ISSSTE SIN                     AHOME
# 2223370            NaN             SANTA MARIA               GUADALAJARA
# 2223371            NaN  SANTA JULIA AMPLIACION           PACHUCA DE SOTO
# 2223377            NaN              El Cerrito              Huauchinango
#
#            FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS FI_ID_TIPOVIVIENDA  \
# 1              NUEVO LEON           66450  MEXICO                  3
# 3                VERACRUZ           91615  MEXICO                  3
# 7                 YUCATAN           97000  MEXICO                  3
# 9        DISTRITO FEDERAL           06720  MEXICO                  3
# 10               VERACRUZ           95400  MEXICO                  3
# ...                   ...             ...     ...                ...
# 2223365            OAXACA           68297  MEXICO                  3
# 2223366           SINALOA           81215  MEXICO                  3
# 2223370           JALISCO           44350  Mexico                  3
# 2223371           HIDALGO           42080  Mexico                  3
# 2223377            PUEBLA           73160  MEXICO                  3
#
#         FC_ID_TIPOVIVIENDA           FC_LATITUD            FC_LONGITUD  \
# 1                   PROPIA  25.7328120000000000  -100.2946250000000000
# 3                   PROPIA  19.3860900000000000   -96.9746210000000000
# 7                   PROPIA  20.9709650000000000   -89.6251680000000000
# 9                   PROPIA  19.4168930000000000   -99.1486160000000000
# 10                  PROPIA  18.3677680000000000   -95.7917570000000000
# ...                    ...                  ...                    ...
# 2223365             PROPIA  17.0500750000000000   -96.6265490000000000
# 2223366             PROPIA  25.8090870000000000  -108.9758730000000000
# 2223370             PROPIA  20.6873130000000000  -103.3135330000000000
# 2223371             PROPIA  20.1105960000000000   -98.7668020000000000
# 2223377             PROPIA  20.1555560000000000   -98.0343770000000000
#
#         FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO FC_ID_ESTADO FI_ID_PAIS
# 1               NaN             2              46           19          1
# 3               NaN             1             164           30          1
# 7               NaN             1              50           31          1
# 9               NaN             1               6            9          1
# 10              NaN            40              45           30          1
# ...             ...           ...             ...          ...        ...
# 2223365         NaN             4             409           20          1
# 2223366         NaN             1               1           25          1
# 2223370         NaN             5              39           14          1
# 2223371         NaN            10              48           13          1
# 2223377         NaN            25              71           21          1
#
# [640689 rows x 19 columns]

# %%
subset = dispersiones.merge(domicilios, on='FI_EMPLEADO')

# %%
test = dispersiones.merge(domicilios, on='FI_EMPLEADO').merge(demograficos, on='FI_EMPLEADO')

# %%
test = test.sample(n=1000)

# %%
test
# Out:
#        #FI_ID_INSTITUCION_x FI_EMPLEADO             FC_CUENTA  \
# 25722                  4673      254435  01278765750107254356
# 182346                11879     2464687  01274802600120925148
# 24235                  4673      261468  01278684360181466578
# 93552                  4673     1530516  01270602181342037346
# 208417                 4673     2684580  01279740110141696900
# ...                     ...         ...                   ...
# 104382                 4673     1640908  01272196061318642100
# 86232                  5383     1391944  01275116860132501362
# 171619                 5383     2347521  01273278040152027698
# 32713                  4673      311643  01272080250173879726
# 15933                  4673      197140  01272063110197317386
#
#             FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 25722   11/30/2021 00:00:00               7     2795.84             MENSUAL
# 182346  12/09/2021 00:00:00              18     4851.71             SEMANAL
# 24235   11/30/2021 00:00:00               7     3224.77             MENSUAL
# 93552   11/30/2021 00:00:00               7     4724.67             MENSUAL
# 208417  11/30/2021 00:00:00               5    15370.32             MENSUAL
# ...                     ...             ...         ...                 ...
# 104382  11/30/2021 00:00:00               7    32709.01             MENSUAL
# 86232   11/30/2021 00:00:00               8     5652.40             MENSUAL
# 171619  11/16/2021 00:00:00               6     4310.00             MENSUAL
# 32713   11/30/2021 00:00:00               7     3054.92             MENSUAL
# 15933   11/30/2021 00:00:00               7     2945.11             MENSUAL
#
#        FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 25722               NaN            PENSIONADOS Y JUBILADOS             11
# 182346              NaN                      NOMINA AZTECA             10
# 24235               NaN            PENSIONADOS Y JUBILADOS             11
# 93552               NaN            PENSIONADOS Y JUBILADOS             11
# 208417              NaN            PENSIONADOS Y JUBILADOS             11
# ...                 ...                                ...            ...
# 104382              NaN            PENSIONADOS Y JUBILADOS             11
# 86232               NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 171619              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 32713               NaN            PENSIONADOS Y JUBILADOS             11
# 15933               NaN            PENSIONADOS Y JUBILADOS             11
#
#         ... FC_APELLIDO_PATERNO  FC_APELLIDO_MATERNO FI_ID_PAIS_y  \
# 25722   ...              GARCIA                LOPEZ            1
# 182346  ...                DIAZ                  LEY            1
# 24235   ...          DE LA CRUZ               ISLENO            1
# 93552   ...                 NaN              RAMIREZ            1
# 208417  ...             INFANTE                 MATA            1
# ...     ...                 ...                  ...          ...
# 104382  ...                DIAZ            HERNANDEZ            1
# 86232   ...              FISHER               MELGAR            1
# 171619  ...            CARRILLO                AMAYA            1
# 32713   ...            MARTINEZ            DOMINGUEZ            1
# 15933   ...              GARCIA               VALDEZ            1
#
#               FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO FNESTADOCIVIL  \
# 25722   03/28/2018 00:00:00                1              28             5
# 182346  12/06/2020 00:00:00                1              28             2
# 24235   03/28/2018 00:00:00                1              30             2
# 93552                   NaN                1              11             3
# 208417  12/08/2020 00:00:00                1              24             2
# ...                     ...              ...             ...           ...
# 104382                  NaN                1              20             3
# 86232   03/11/2020 16:58:21                1               3             0
# 171619  12/05/2020 00:00:00                1              31             1
# 32713   10/18/2016 00:00:00                1               9             2
# 15933   12/28/2011 00:00:00                1              15             1
#
#        FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 25722              7      1            484
# 182346             7      1            484
# 24235              7      2            484
# 93552              7      2            484
# 208417             7      2            484
# ...              ...    ...            ...
# 104382             7      2            484
# 86232              7      1            484
# 171619             7      2            484
# 32713              7      2            484
# 15933              7      1            484
#
# [1000 rows x 72 columns]

# %%
test.columns
# Out:
# Index(['#FI_ID_INSTITUCION_x', 'FI_EMPLEADO', 'FC_CUENTA', 'FD_ULTIMADISPER',
#        'FI_TOTALDISPER', 'FN_SALARIO', 'FC_PERIODICIDADPAGO',
#        'FI_CAPACIDADPAGO', 'FC_PRODUCTO', 'FI_ID_PRODUCTO', 'FI_CREDITOSACTIV',
#        'FIPERIODICIDADPAGO', 'FI_CTA_DIGITOS', '#FI_ID_INSTITUCION_y',
#        'FC_CALLEHOGAR', 'FC_NUMEXTHOGAR', 'FC_NUMINTHOGAR', 'FC_COLONIAHOGAR',
#        'FC_MUNICIPIOHOGAR', 'FC_ESTADOHOGAR', 'FC_CODIGOPOSTAL', 'FC_PAIS',
#        'FI_ID_TIPOVIVIENDA', 'FC_ID_TIPOVIVIENDA', 'FC_LATITUD', 'FC_LONGITUD',
#        'FC_SUCURSAL', 'FI_ID_COLONIA', 'FI_ID_MUNICIPIO', 'FC_ID_ESTADO',
#        'FI_ID_PAIS_x', '#FI_ID_INSTITUCION', 'FI_PAISCU', 'FI_CANALCU',
#        'FI_SUCURSALCU', 'FI_FOLIOCU', 'FC_INSTITUCION', 'FC_NOMBRECOMPLETO',
#        'FD_FECHANACIMIENTO', 'FC_PAISNACIMIENTO', 'FC_ESTADONACIMIENTO',
#        'FI_EDAD', 'FC_RFC', 'FC_CURP', 'FC_NSS', 'FC_ESTADOCIVIL',
#        'FC_ESCOLARIDAD', 'FC_SEXO', 'FC_TELEFONOCASA', 'FC_TELCELULAR',
#        'FC_EMAIL', 'FC_AVISOPRIVACIDAD', 'FC_CONSULTABURO',
#        'FC_USODATOSPERSONA', 'FC_USODATOSPROMO', 'FC_NACIONALIDAD',
#        'FD_ALTAEMPLEADO', 'FI_DATOS_CORRECTOS', 'FI_OFERTA', 'FC_STATUS_EMP',
#        'FI_STATUS_EMP', 'FC_NOMBRE_EMPLEADO', 'FC_APELLIDO_PATERNO',
#        'FC_APELLIDO_MATERNO', 'FI_ID_PAIS_y', 'FD_FECHA_ALTA',
#        'FNPAISNACIMIENTO', 'FNEDONACIMIENTO', 'FNESTADOCIVIL', 'FNESCOLARIDAD',
#        'FNSEXO', 'FNNACIONALIDAD'],
#       dtype='object')

# %%
m_demograficos = test[['#FI_ID_INSTITUCION', 'FI_EMPLEADO', 'FI_PAISCU', 'FI_CANALCU',
       'FI_SUCURSALCU', 'FI_FOLIOCU', 'FC_INSTITUCION', 'FC_NOMBRECOMPLETO',
       'FD_FECHANACIMIENTO', 'FC_PAISNACIMIENTO', 'FC_ESTADONACIMIENTO',
       'FI_EDAD', 'FC_RFC', 'FC_CURP', 'FC_NSS', 'FC_ESTADOCIVIL',
       'FC_ESCOLARIDAD', 'FC_SEXO', 'FC_TELEFONOCASA', 'FC_TELCELULAR',
       'FC_EMAIL', 'FC_AVISOPRIVACIDAD', 'FC_CONSULTABURO',
       'FC_USODATOSPERSONA', 'FC_USODATOSPROMO', 'FC_NACIONALIDAD',
       'FD_ALTAEMPLEADO', 'FI_DATOS_CORRECTOS', 'FI_OFERTA', 'FC_STATUS_EMP',
       'FI_STATUS_EMP', 'FC_NOMBRE_EMPLEADO', 'FC_APELLIDO_PATERNO',
       'FC_APELLIDO_MATERNO', 'FI_ID_PAIS_y', 'FD_FECHA_ALTA',
       'FNPAISNACIMIENTO', 'FNEDONACIMIENTO', 'FNESTADOCIVIL', 'FNESCOLARIDAD',
       'FNSEXO', 'FNNACIONALIDAD']]

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 25722                4673      254435         1          1          8765
# 182346              11879     2464687         1          1          4802
# 24235                4673      261468         1          1          3638
# 93552                4673     1530516         1          1           602
# 208417               4673     2684580         1          1          9740
# ...                   ...         ...       ...        ...           ...
# 104382               4673     1640908         1          1          2196
# 86232                5383     1391944         1          1          5116
# 171619               5383     2347521         1          9          3278
# 32713                4673      311643         1         20          9259
# 15933                4673      197140         1          1          2063
#
#        FI_FOLIOCU           FC_INSTITUCION  \
# 25722       71946         IMSS PENSIONADOS
# 182346      41971   CUTSPEI SIN CLASIFICAR
# 24235       32139         IMSS PENSIONADOS
# 93552       65685         IMSS PENSIONADOS
# 208417       4858         IMSS PENSIONADOS
# ...           ...                      ...
# 104382       3343         IMSS PENSIONADOS
# 86232       27596  BAZ PORTABILIDAD NOMINA
# 171619       7175  BAZ PORTABILIDAD NOMINA
# 32713        5969         IMSS PENSIONADOS
# 15933       41524         IMSS PENSIONADOS
#
#                          FC_NOMBRECOMPLETO   FD_FECHANACIMIENTO  \
# 25722        MARIA MONCERRATO GARCIA LOPEZ  10/27/1938 00:00:00
# 182346                  ANA VELIA DIAZ LEY  12/03/1970 00:00:00
# 24235            PROCORO DE LA CRUZ ISLENO  04/09/1944 00:00:00
# 93552                      MARCOS  RAMIREZ  12/25/1945 00:00:00
# 208417                BERNABE INFANTE MATA  12/06/1960 00:00:00
# ...                                    ...                  ...
# 104382          LUIS JAVIER DIAZ HERNANDEZ  04/08/1960 00:00:00
# 86232   GUADALUPE CONCEPCION FISHER MELGAR  09/15/1965 00:00:00
# 171619       RICARDO ALONSO CARRILLO AMAYA  12/08/1991 00:00:00
# 32713           RODOLFO MARTINEZ DOMINGUEZ  09/27/1936 12:00:00
# 15933                  ELENA GARCIA VALDEZ  02/03/1942 00:00:00
#
#        FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO FC_APELLIDO_MATERNO  \
# 25722             MEXICO  ...              GARCIA               LOPEZ
# 182346               NaN  ...                DIAZ                 LEY
# 24235             MEXICO  ...          DE LA CRUZ              ISLENO
# 93552                NaN  ...                 NaN             RAMIREZ
# 208417               NaN  ...             INFANTE                MATA
# ...                  ...  ...                 ...                 ...
# 104382               NaN  ...                DIAZ           HERNANDEZ
# 86232                NaN  ...              FISHER              MELGAR
# 171619               NaN  ...            CARRILLO               AMAYA
# 32713                NaN  ...            MARTINEZ           DOMINGUEZ
# 15933             MEXICO  ...              GARCIA              VALDEZ
#
#        FI_ID_PAIS_y        FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO  \
# 25722             1  03/28/2018 00:00:00                1              28
# 182346            1  12/06/2020 00:00:00                1              28
# 24235             1  03/28/2018 00:00:00                1              30
# 93552             1                  NaN                1              11
# 208417            1  12/08/2020 00:00:00                1              24
# ...             ...                  ...              ...             ...
# 104382            1                  NaN                1              20
# 86232             1  03/11/2020 16:58:21                1               3
# 171619            1  12/05/2020 00:00:00                1              31
# 32713             1  10/18/2016 00:00:00                1               9
# 15933             1  12/28/2011 00:00:00                1              15
#
#        FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 25722              5             7      1            484
# 182346             2             7      1            484
# 24235              2             7      2            484
# 93552              3             7      2            484
# 208417             2             7      2            484
# ...              ...           ...    ...            ...
# 104382             3             7      2            484
# 86232              0             7      1            484
# 171619             1             7      2            484
# 32713              2             7      2            484
# 15933              1             7      1            484
#
# [1000 rows x 42 columns]

# %%
m_dispersiones = test[['#FI_ID_INSTITUCION_x', 'FI_EMPLEADO', 'FC_CUENTA', 'FD_ULTIMADISPER',
       'FI_TOTALDISPER', 'FN_SALARIO', 'FC_PERIODICIDADPAGO',
       'FI_CAPACIDADPAGO', 'FC_PRODUCTO', 'FI_ID_PRODUCTO', 'FI_CREDITOSACTIV',
       'FIPERIODICIDADPAGO', 'FI_CTA_DIGITOS']]

# %%
m_dispersiones
# Out:
#        #FI_ID_INSTITUCION_x FI_EMPLEADO             FC_CUENTA  \
# 25722                  4673      254435  01278765750107254356
# 182346                11879     2464687  01274802600120925148
# 24235                  4673      261468  01278684360181466578
# 93552                  4673     1530516  01270602181342037346
# 208417                 4673     2684580  01279740110141696900
# ...                     ...         ...                   ...
# 104382                 4673     1640908  01272196061318642100
# 86232                  5383     1391944  01275116860132501362
# 171619                 5383     2347521  01273278040152027698
# 32713                  4673      311643  01272080250173879726
# 15933                  4673      197140  01272063110197317386
#
#             FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 25722   11/30/2021 00:00:00               7     2795.84             MENSUAL
# 182346  12/09/2021 00:00:00              18     4851.71             SEMANAL
# 24235   11/30/2021 00:00:00               7     3224.77             MENSUAL
# 93552   11/30/2021 00:00:00               7     4724.67             MENSUAL
# 208417  11/30/2021 00:00:00               5    15370.32             MENSUAL
# ...                     ...             ...         ...                 ...
# 104382  11/30/2021 00:00:00               7    32709.01             MENSUAL
# 86232   11/30/2021 00:00:00               8     5652.40             MENSUAL
# 171619  11/16/2021 00:00:00               6     4310.00             MENSUAL
# 32713   11/30/2021 00:00:00               7     3054.92             MENSUAL
# 15933   11/30/2021 00:00:00               7     2945.11             MENSUAL
#
#        FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 25722               NaN            PENSIONADOS Y JUBILADOS             11
# 182346              NaN                      NOMINA AZTECA             10
# 24235               NaN            PENSIONADOS Y JUBILADOS             11
# 93552               NaN            PENSIONADOS Y JUBILADOS             11
# 208417              NaN            PENSIONADOS Y JUBILADOS             11
# ...                 ...                                ...            ...
# 104382              NaN            PENSIONADOS Y JUBILADOS             11
# 86232               NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 171619              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 32713               NaN            PENSIONADOS Y JUBILADOS             11
# 15933               NaN            PENSIONADOS Y JUBILADOS             11
#
#        FI_CREDITOSACTIV  FIPERIODICIDADPAGO FI_CTA_DIGITOS
# 25722                 0                   3      107254356
# 182346                0                   1      120925148
# 24235                 0                   3      181466578
# 93552                 1                   3     1342037346
# 208417                0                   3      141696900
# ...                 ...                 ...            ...
# 104382                0                   3     1318642100
# 86232                 0                   3      132501362
# 171619                0                   3      152027698
# 32713                 0                   3      173879726
# 15933                 0                   3      197317386
#
# [1000 rows x 13 columns]

# %%
m_domicilios = test[['#FI_ID_INSTITUCION_y', 'FI_EMPLEADO',
       'FC_CALLEHOGAR', 'FC_NUMEXTHOGAR', 'FC_NUMINTHOGAR', 'FC_COLONIAHOGAR',
       'FC_MUNICIPIOHOGAR', 'FC_ESTADOHOGAR', 'FC_CODIGOPOSTAL', 'FC_PAIS',
       'FI_ID_TIPOVIVIENDA', 'FC_ID_TIPOVIVIENDA', 'FC_LATITUD', 'FC_LONGITUD',
       'FC_SUCURSAL', 'FI_ID_COLONIA', 'FI_ID_MUNICIPIO', 'FC_ID_ESTADO',
       'FI_ID_PAIS_x']]

# %%
m_demograficos.columns
# Out:
# Index(['#FI_ID_INSTITUCION', 'FI_EMPLEADO', 'FI_PAISCU', 'FI_CANALCU',
#        'FI_SUCURSALCU', 'FI_FOLIOCU', 'FC_INSTITUCION', 'FC_NOMBRECOMPLETO',
#        'FD_FECHANACIMIENTO', 'FC_PAISNACIMIENTO', 'FC_ESTADONACIMIENTO',
#        'FI_EDAD', 'FC_RFC', 'FC_CURP', 'FC_NSS', 'FC_ESTADOCIVIL',
#        'FC_ESCOLARIDAD', 'FC_SEXO', 'FC_TELEFONOCASA', 'FC_TELCELULAR',
#        'FC_EMAIL', 'FC_AVISOPRIVACIDAD', 'FC_CONSULTABURO',
#        'FC_USODATOSPERSONA', 'FC_USODATOSPROMO', 'FC_NACIONALIDAD',
#        'FD_ALTAEMPLEADO', 'FI_DATOS_CORRECTOS', 'FI_OFERTA', 'FC_STATUS_EMP',
#        'FI_STATUS_EMP', 'FC_NOMBRE_EMPLEADO', 'FC_APELLIDO_PATERNO',
#        'FC_APELLIDO_MATERNO', 'FI_ID_PAIS_y', 'FD_FECHA_ALTA',
#        'FNPAISNACIMIENTO', 'FNEDONACIMIENTO', 'FNESTADOCIVIL', 'FNESCOLARIDAD',
#        'FNSEXO', 'FNNACIONALIDAD'],
#       dtype='object')

# %%
m_demograficos.rename(columns={'FI_ID_PAIS_y':'FI_ID_PAIS'}, inplace=True)
# Out:
# /Users/ilucash/Documents/Proyectos/BIG/NAC/venv/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 25722                4673      254435         1          1          8765
# 182346              11879     2464687         1          1          4802
# 24235                4673      261468         1          1          3638
# 93552                4673     1530516         1          1           602
# 208417               4673     2684580         1          1          9740
# ...                   ...         ...       ...        ...           ...
# 104382               4673     1640908         1          1          2196
# 86232                5383     1391944         1          1          5116
# 171619               5383     2347521         1          9          3278
# 32713                4673      311643         1         20          9259
# 15933                4673      197140         1          1          2063
#
#        FI_FOLIOCU           FC_INSTITUCION  \
# 25722       71946         IMSS PENSIONADOS
# 182346      41971   CUTSPEI SIN CLASIFICAR
# 24235       32139         IMSS PENSIONADOS
# 93552       65685         IMSS PENSIONADOS
# 208417       4858         IMSS PENSIONADOS
# ...           ...                      ...
# 104382       3343         IMSS PENSIONADOS
# 86232       27596  BAZ PORTABILIDAD NOMINA
# 171619       7175  BAZ PORTABILIDAD NOMINA
# 32713        5969         IMSS PENSIONADOS
# 15933       41524         IMSS PENSIONADOS
#
#                          FC_NOMBRECOMPLETO   FD_FECHANACIMIENTO  \
# 25722        MARIA MONCERRATO GARCIA LOPEZ  10/27/1938 00:00:00
# 182346                  ANA VELIA DIAZ LEY  12/03/1970 00:00:00
# 24235            PROCORO DE LA CRUZ ISLENO  04/09/1944 00:00:00
# 93552                      MARCOS  RAMIREZ  12/25/1945 00:00:00
# 208417                BERNABE INFANTE MATA  12/06/1960 00:00:00
# ...                                    ...                  ...
# 104382          LUIS JAVIER DIAZ HERNANDEZ  04/08/1960 00:00:00
# 86232   GUADALUPE CONCEPCION FISHER MELGAR  09/15/1965 00:00:00
# 171619       RICARDO ALONSO CARRILLO AMAYA  12/08/1991 00:00:00
# 32713           RODOLFO MARTINEZ DOMINGUEZ  09/27/1936 12:00:00
# 15933                  ELENA GARCIA VALDEZ  02/03/1942 00:00:00
#
#        FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO FC_APELLIDO_MATERNO  \
# 25722             MEXICO  ...              GARCIA               LOPEZ
# 182346               NaN  ...                DIAZ                 LEY
# 24235             MEXICO  ...          DE LA CRUZ              ISLENO
# 93552                NaN  ...                 NaN             RAMIREZ
# 208417               NaN  ...             INFANTE                MATA
# ...                  ...  ...                 ...                 ...
# 104382               NaN  ...                DIAZ           HERNANDEZ
# 86232                NaN  ...              FISHER              MELGAR
# 171619               NaN  ...            CARRILLO               AMAYA
# 32713                NaN  ...            MARTINEZ           DOMINGUEZ
# 15933             MEXICO  ...              GARCIA              VALDEZ
#
#        FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO  \
# 25722           1  03/28/2018 00:00:00                1              28
# 182346          1  12/06/2020 00:00:00                1              28
# 24235           1  03/28/2018 00:00:00                1              30
# 93552           1                  NaN                1              11
# 208417          1  12/08/2020 00:00:00                1              24
# ...           ...                  ...              ...             ...
# 104382          1                  NaN                1              20
# 86232           1  03/11/2020 16:58:21                1               3
# 171619          1  12/05/2020 00:00:00                1              31
# 32713           1  10/18/2016 00:00:00                1               9
# 15933           1  12/28/2011 00:00:00                1              15
#
#        FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 25722              5             7      1            484
# 182346             2             7      1            484
# 24235              2             7      2            484
# 93552              3             7      2            484
# 208417             2             7      2            484
# ...              ...           ...    ...            ...
# 104382             3             7      2            484
# 86232              0             7      1            484
# 171619             1             7      2            484
# 32713              2             7      2            484
# 15933              1             7      1            484
#
# [1000 rows x 42 columns]

# %%
m_dispersiones.columns
# Out:
# Index(['#FI_ID_INSTITUCION_x', 'FI_EMPLEADO', 'FC_CUENTA', 'FD_ULTIMADISPER',
#        'FI_TOTALDISPER', 'FN_SALARIO', 'FC_PERIODICIDADPAGO',
#        'FI_CAPACIDADPAGO', 'FC_PRODUCTO', 'FI_ID_PRODUCTO', 'FI_CREDITOSACTIV',
#        'FIPERIODICIDADPAGO', 'FI_CTA_DIGITOS'],
#       dtype='object')

# %%
m_dispersiones.rename(columns={'#FI_ID_INSTITUCION_x':'#FI_ID_INSTITUCION'}, inplace=True)
# Out:
# /Users/ilucash/Documents/Proyectos/BIG/NAC/venv/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 25722                4673      254435         1          1          8765
# 182346              11879     2464687         1          1          4802
# 24235                4673      261468         1          1          3638
# 93552                4673     1530516         1          1           602
# 208417               4673     2684580         1          1          9740
# ...                   ...         ...       ...        ...           ...
# 104382               4673     1640908         1          1          2196
# 86232                5383     1391944         1          1          5116
# 171619               5383     2347521         1          9          3278
# 32713                4673      311643         1         20          9259
# 15933                4673      197140         1          1          2063
#
#        FI_FOLIOCU           FC_INSTITUCION  \
# 25722       71946         IMSS PENSIONADOS
# 182346      41971   CUTSPEI SIN CLASIFICAR
# 24235       32139         IMSS PENSIONADOS
# 93552       65685         IMSS PENSIONADOS
# 208417       4858         IMSS PENSIONADOS
# ...           ...                      ...
# 104382       3343         IMSS PENSIONADOS
# 86232       27596  BAZ PORTABILIDAD NOMINA
# 171619       7175  BAZ PORTABILIDAD NOMINA
# 32713        5969         IMSS PENSIONADOS
# 15933       41524         IMSS PENSIONADOS
#
#                          FC_NOMBRECOMPLETO   FD_FECHANACIMIENTO  \
# 25722        MARIA MONCERRATO GARCIA LOPEZ  10/27/1938 00:00:00
# 182346                  ANA VELIA DIAZ LEY  12/03/1970 00:00:00
# 24235            PROCORO DE LA CRUZ ISLENO  04/09/1944 00:00:00
# 93552                      MARCOS  RAMIREZ  12/25/1945 00:00:00
# 208417                BERNABE INFANTE MATA  12/06/1960 00:00:00
# ...                                    ...                  ...
# 104382          LUIS JAVIER DIAZ HERNANDEZ  04/08/1960 00:00:00
# 86232   GUADALUPE CONCEPCION FISHER MELGAR  09/15/1965 00:00:00
# 171619       RICARDO ALONSO CARRILLO AMAYA  12/08/1991 00:00:00
# 32713           RODOLFO MARTINEZ DOMINGUEZ  09/27/1936 12:00:00
# 15933                  ELENA GARCIA VALDEZ  02/03/1942 00:00:00
#
#        FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO FC_APELLIDO_MATERNO  \
# 25722             MEXICO  ...              GARCIA               LOPEZ
# 182346               NaN  ...                DIAZ                 LEY
# 24235             MEXICO  ...          DE LA CRUZ              ISLENO
# 93552                NaN  ...                 NaN             RAMIREZ
# 208417               NaN  ...             INFANTE                MATA
# ...                  ...  ...                 ...                 ...
# 104382               NaN  ...                DIAZ           HERNANDEZ
# 86232                NaN  ...              FISHER              MELGAR
# 171619               NaN  ...            CARRILLO               AMAYA
# 32713                NaN  ...            MARTINEZ           DOMINGUEZ
# 15933             MEXICO  ...              GARCIA              VALDEZ
#
#        FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO  \
# 25722           1  03/28/2018 00:00:00                1              28
# 182346          1  12/06/2020 00:00:00                1              28
# 24235           1  03/28/2018 00:00:00                1              30
# 93552           1                  NaN                1              11
# 208417          1  12/08/2020 00:00:00                1              24
# ...           ...                  ...              ...             ...
# 104382          1                  NaN                1              20
# 86232           1  03/11/2020 16:58:21                1               3
# 171619          1  12/05/2020 00:00:00                1              31
# 32713           1  10/18/2016 00:00:00                1               9
# 15933           1  12/28/2011 00:00:00                1              15
#
#        FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 25722              5             7      1            484
# 182346             2             7      1            484
# 24235              2             7      2            484
# 93552              3             7      2            484
# 208417             2             7      2            484
# ...              ...           ...    ...            ...
# 104382             3             7      2            484
# 86232              0             7      1            484
# 171619             1             7      2            484
# 32713              2             7      2            484
# 15933              1             7      1            484
#
# [1000 rows x 42 columns]

# %%
m_domicilios.columns
# Out:
# Index(['#FI_ID_INSTITUCION_y', 'FI_EMPLEADO', 'FC_CALLEHOGAR',
#        'FC_NUMEXTHOGAR', 'FC_NUMINTHOGAR', 'FC_COLONIAHOGAR',
#        'FC_MUNICIPIOHOGAR', 'FC_ESTADOHOGAR', 'FC_CODIGOPOSTAL', 'FC_PAIS',
#        'FI_ID_TIPOVIVIENDA', 'FC_ID_TIPOVIVIENDA', 'FC_LATITUD', 'FC_LONGITUD',
#        'FC_SUCURSAL', 'FI_ID_COLONIA', 'FI_ID_MUNICIPIO', 'FC_ID_ESTADO',
#        'FI_ID_PAIS_x'],
#       dtype='object')

# %%
m_domicilios.rename(columns={'#FI_ID_INSTITUCION_y':'#FI_ID_INSTITUCION','FI_ID_PAIS_x':'FI_ID_PAIS'}, inplace=True)
# Out:
# /Users/ilucash/Documents/Proyectos/BIG/NAC/venv/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
m_domicilios
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO         FC_CALLEHOGAR FC_NUMEXTHOGAR  \
# 25722                4673      254435       PROFESOR ROMERO             94
# 182346              11879     2464687           C SN NOMBRE             SN
# 24235                4673      261468       RAFAEL SUAREZ R             SN
# 93552                4673     1530516                  ARCE            112
# 208417               4673     2684580     C REFORMA AGRARIA           2153
# ...                   ...         ...                   ...            ...
# 104382               4673     1640908  PRIV 1RA DE LA NORIA            105
# 86232                5383     1391944             SAN PEDRO             SN
# 171619               5383     2347521        C 40 X 27 Y 29             SN
# 32713                4673      311643           AVENIDA 521            233
# 15933                4673      197140        AMADOR SALAZAR          MZ 47
#
#        FC_NUMINTHOGAR          FC_COLONIAHOGAR            FC_MUNICIPIOHOGAR  \
# 25722              94               BUENAVISTA                    MATAMOROS
# 182346            NaN           EJIDO EL OLIVO                     VICTORIA
# 24235              SN       GUADALUPE VICTORIA         POZA RICA DE HIDALGO
# 93552             NaN            Las Arboledas                         León
# 208417            NaN    GENOVEVO RIVAS GILLEN  SOLEDAD DE GRACIANO SANCHEZ
# ...               ...                      ...                          ...
# 104382            NaN            OAXACA CENTRO             Oaxaca de Juárez
# 86232             NaN                San Pedro                       La Paz
# 171619             SN                 TZUCACAB                    OXKUTZCAB
# 32713             NaN  U H. SAN JUAN DE ARAGON            GUSTAVO A. MADERO
# 15933            LT 5             LA ESPERANZA          ECATEPEC DE MORELOS
#
#              FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS FI_ID_TIPOVIVIENDA  \
# 25722            TAMAULIPAS           87350  MEXICO                  3
# 182346           TAMAULIPAS           87000  MEXICO                  3
# 24235              VERACRUZ           93290  MEXICO                  3
# 93552            GUANAJUATO           37480  MEXICO                  3
# 208417      SAN LUIS POTOSI           78437  Mexico                  3
# ...                     ...             ...     ...                ...
# 104382               OAXACA           68000  MEXICO                  3
# 86232   BAJA CALIFORNIA SUR           23240  MEXICO                  3
# 171619              YUCATAN           97960  Mexico                  3
# 32713      DISTRITO FEDERAL           07920  MEXICO                  3
# 15933      ESTADO DE MEXICO           55050  MEXICO                  3
#
#        FC_ID_TIPOVIVIENDA           FC_LATITUD            FC_LONGITUD  \
# 25722              PROPIA  25.8656260000000000   -97.5178210000000000
# 182346             PROPIA  23.7303730000000000   -99.1479870000000000
# 24235              PROPIA  20.5200440000000000   -97.4249770000000000
# 93552              PROPIA  21.1030560000000000  -101.6649800000000000
# 208417             PROPIA  22.1574780000000000  -100.9239080000000000
# ...                   ...                  ...                    ...
# 104382             PROPIA  17.0556610000000000   -96.7215940000000000
# 86232              PROPIA  23.9413780000000000  -110.2722820000000000
# 171619             PROPIA  20.0729550000000000   -89.0484910000000000
# 32713              PROPIA  19.4735680000000000   -99.0867350000000000
# 15933              PROPIA  19.6008570000000000   -99.0170590000000000
#
#        FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO FC_ID_ESTADO FI_ID_PAIS
# 25722          NaN             1              22           28          1
# 182346         NaN            59              41           28          1
# 24235          NaN             1             131           30          1
# 93552          NaN             3              20           11          1
# 208417         NaN            14              35           24          1
# ...            ...           ...             ...          ...        ...
# 104382         NaN             1              67           20          1
# 86232          NaN             1               3            3          1
# 171619         NaN             1              98           31          1
# 32713          NaN             3               7            9          1
# 15933          NaN             9              33           15          1
#
# [1000 rows x 19 columns]

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 25722                4673      254435         1          1          8765
# 182346              11879     2464687         1          1          4802
# 24235                4673      261468         1          1          3638
# 93552                4673     1530516         1          1           602
# 208417               4673     2684580         1          1          9740
# ...                   ...         ...       ...        ...           ...
# 104382               4673     1640908         1          1          2196
# 86232                5383     1391944         1          1          5116
# 171619               5383     2347521         1          9          3278
# 32713                4673      311643         1         20          9259
# 15933                4673      197140         1          1          2063
#
#        FI_FOLIOCU           FC_INSTITUCION  \
# 25722       71946         IMSS PENSIONADOS
# 182346      41971   CUTSPEI SIN CLASIFICAR
# 24235       32139         IMSS PENSIONADOS
# 93552       65685         IMSS PENSIONADOS
# 208417       4858         IMSS PENSIONADOS
# ...           ...                      ...
# 104382       3343         IMSS PENSIONADOS
# 86232       27596  BAZ PORTABILIDAD NOMINA
# 171619       7175  BAZ PORTABILIDAD NOMINA
# 32713        5969         IMSS PENSIONADOS
# 15933       41524         IMSS PENSIONADOS
#
#                          FC_NOMBRECOMPLETO   FD_FECHANACIMIENTO  \
# 25722        MARIA MONCERRATO GARCIA LOPEZ  10/27/1938 00:00:00
# 182346                  ANA VELIA DIAZ LEY  12/03/1970 00:00:00
# 24235            PROCORO DE LA CRUZ ISLENO  04/09/1944 00:00:00
# 93552                      MARCOS  RAMIREZ  12/25/1945 00:00:00
# 208417                BERNABE INFANTE MATA  12/06/1960 00:00:00
# ...                                    ...                  ...
# 104382          LUIS JAVIER DIAZ HERNANDEZ  04/08/1960 00:00:00
# 86232   GUADALUPE CONCEPCION FISHER MELGAR  09/15/1965 00:00:00
# 171619       RICARDO ALONSO CARRILLO AMAYA  12/08/1991 00:00:00
# 32713           RODOLFO MARTINEZ DOMINGUEZ  09/27/1936 12:00:00
# 15933                  ELENA GARCIA VALDEZ  02/03/1942 00:00:00
#
#        FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO FC_APELLIDO_MATERNO  \
# 25722             MEXICO  ...              GARCIA               LOPEZ
# 182346               NaN  ...                DIAZ                 LEY
# 24235             MEXICO  ...          DE LA CRUZ              ISLENO
# 93552                NaN  ...                 NaN             RAMIREZ
# 208417               NaN  ...             INFANTE                MATA
# ...                  ...  ...                 ...                 ...
# 104382               NaN  ...                DIAZ           HERNANDEZ
# 86232                NaN  ...              FISHER              MELGAR
# 171619               NaN  ...            CARRILLO               AMAYA
# 32713                NaN  ...            MARTINEZ           DOMINGUEZ
# 15933             MEXICO  ...              GARCIA              VALDEZ
#
#        FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO  \
# 25722           1  03/28/2018 00:00:00                1              28
# 182346          1  12/06/2020 00:00:00                1              28
# 24235           1  03/28/2018 00:00:00                1              30
# 93552           1                  NaN                1              11
# 208417          1  12/08/2020 00:00:00                1              24
# ...           ...                  ...              ...             ...
# 104382          1                  NaN                1              20
# 86232           1  03/11/2020 16:58:21                1               3
# 171619          1  12/05/2020 00:00:00                1              31
# 32713           1  10/18/2016 00:00:00                1               9
# 15933           1  12/28/2011 00:00:00                1              15
#
#        FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 25722              5             7      1            484
# 182346             2             7      1            484
# 24235              2             7      2            484
# 93552              3             7      2            484
# 208417             2             7      2            484
# ...              ...           ...    ...            ...
# 104382             3             7      2            484
# 86232              0             7      1            484
# 171619             1             7      2            484
# 32713              2             7      2            484
# 15933              1             7      1            484
#
# [1000 rows x 42 columns]

# %%
m_dispersiones
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO             FC_CUENTA  \
# 25722                4673      254435  01278765750107254356
# 182346              11879     2464687  01274802600120925148
# 24235                4673      261468  01278684360181466578
# 93552                4673     1530516  01270602181342037346
# 208417               4673     2684580  01279740110141696900
# ...                   ...         ...                   ...
# 104382               4673     1640908  01272196061318642100
# 86232                5383     1391944  01275116860132501362
# 171619               5383     2347521  01273278040152027698
# 32713                4673      311643  01272080250173879726
# 15933                4673      197140  01272063110197317386
#
#             FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 25722   11/30/2021 00:00:00               7     2795.84             MENSUAL
# 182346  12/09/2021 00:00:00              18     4851.71             SEMANAL
# 24235   11/30/2021 00:00:00               7     3224.77             MENSUAL
# 93552   11/30/2021 00:00:00               7     4724.67             MENSUAL
# 208417  11/30/2021 00:00:00               5    15370.32             MENSUAL
# ...                     ...             ...         ...                 ...
# 104382  11/30/2021 00:00:00               7    32709.01             MENSUAL
# 86232   11/30/2021 00:00:00               8     5652.40             MENSUAL
# 171619  11/16/2021 00:00:00               6     4310.00             MENSUAL
# 32713   11/30/2021 00:00:00               7     3054.92             MENSUAL
# 15933   11/30/2021 00:00:00               7     2945.11             MENSUAL
#
#        FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 25722               NaN            PENSIONADOS Y JUBILADOS             11
# 182346              NaN                      NOMINA AZTECA             10
# 24235               NaN            PENSIONADOS Y JUBILADOS             11
# 93552               NaN            PENSIONADOS Y JUBILADOS             11
# 208417              NaN            PENSIONADOS Y JUBILADOS             11
# ...                 ...                                ...            ...
# 104382              NaN            PENSIONADOS Y JUBILADOS             11
# 86232               NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 171619              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 32713               NaN            PENSIONADOS Y JUBILADOS             11
# 15933               NaN            PENSIONADOS Y JUBILADOS             11
#
#        FI_CREDITOSACTIV  FIPERIODICIDADPAGO FI_CTA_DIGITOS
# 25722                 0                   3      107254356
# 182346                0                   1      120925148
# 24235                 0                   3      181466578
# 93552                 1                   3     1342037346
# 208417                0                   3      141696900
# ...                 ...                 ...            ...
# 104382                0                   3     1318642100
# 86232                 0                   3      132501362
# 171619                0                   3      152027698
# 32713                 0                   3      173879726
# 15933                 0                   3      197317386
#
# [1000 rows x 13 columns]

# %%
m_domicilios
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO         FC_CALLEHOGAR FC_NUMEXTHOGAR  \
# 25722                4673      254435       PROFESOR ROMERO             94
# 182346              11879     2464687           C SN NOMBRE             SN
# 24235                4673      261468       RAFAEL SUAREZ R             SN
# 93552                4673     1530516                  ARCE            112
# 208417               4673     2684580     C REFORMA AGRARIA           2153
# ...                   ...         ...                   ...            ...
# 104382               4673     1640908  PRIV 1RA DE LA NORIA            105
# 86232                5383     1391944             SAN PEDRO             SN
# 171619               5383     2347521        C 40 X 27 Y 29             SN
# 32713                4673      311643           AVENIDA 521            233
# 15933                4673      197140        AMADOR SALAZAR          MZ 47
#
#        FC_NUMINTHOGAR          FC_COLONIAHOGAR            FC_MUNICIPIOHOGAR  \
# 25722              94               BUENAVISTA                    MATAMOROS
# 182346            NaN           EJIDO EL OLIVO                     VICTORIA
# 24235              SN       GUADALUPE VICTORIA         POZA RICA DE HIDALGO
# 93552             NaN            Las Arboledas                         León
# 208417            NaN    GENOVEVO RIVAS GILLEN  SOLEDAD DE GRACIANO SANCHEZ
# ...               ...                      ...                          ...
# 104382            NaN            OAXACA CENTRO             Oaxaca de Juárez
# 86232             NaN                San Pedro                       La Paz
# 171619             SN                 TZUCACAB                    OXKUTZCAB
# 32713             NaN  U H. SAN JUAN DE ARAGON            GUSTAVO A. MADERO
# 15933            LT 5             LA ESPERANZA          ECATEPEC DE MORELOS
#
#              FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS FI_ID_TIPOVIVIENDA  \
# 25722            TAMAULIPAS           87350  MEXICO                  3
# 182346           TAMAULIPAS           87000  MEXICO                  3
# 24235              VERACRUZ           93290  MEXICO                  3
# 93552            GUANAJUATO           37480  MEXICO                  3
# 208417      SAN LUIS POTOSI           78437  Mexico                  3
# ...                     ...             ...     ...                ...
# 104382               OAXACA           68000  MEXICO                  3
# 86232   BAJA CALIFORNIA SUR           23240  MEXICO                  3
# 171619              YUCATAN           97960  Mexico                  3
# 32713      DISTRITO FEDERAL           07920  MEXICO                  3
# 15933      ESTADO DE MEXICO           55050  MEXICO                  3
#
#        FC_ID_TIPOVIVIENDA           FC_LATITUD            FC_LONGITUD  \
# 25722              PROPIA  25.8656260000000000   -97.5178210000000000
# 182346             PROPIA  23.7303730000000000   -99.1479870000000000
# 24235              PROPIA  20.5200440000000000   -97.4249770000000000
# 93552              PROPIA  21.1030560000000000  -101.6649800000000000
# 208417             PROPIA  22.1574780000000000  -100.9239080000000000
# ...                   ...                  ...                    ...
# 104382             PROPIA  17.0556610000000000   -96.7215940000000000
# 86232              PROPIA  23.9413780000000000  -110.2722820000000000
# 171619             PROPIA  20.0729550000000000   -89.0484910000000000
# 32713              PROPIA  19.4735680000000000   -99.0867350000000000
# 15933              PROPIA  19.6008570000000000   -99.0170590000000000
#
#        FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO FC_ID_ESTADO FI_ID_PAIS
# 25722          NaN             1              22           28          1
# 182346         NaN            59              41           28          1
# 24235          NaN             1             131           30          1
# 93552          NaN             3              20           11          1
# 208417         NaN            14              35           24          1
# ...            ...           ...             ...          ...        ...
# 104382         NaN             1              67           20          1
# 86232          NaN             1               3            3          1
# 171619         NaN             1              98           31          1
# 32713          NaN             3               7            9          1
# 15933          NaN             9              33           15          1
#
# [1000 rows x 19 columns]

# %%
m_domicilios.to_csv('DM_DatosDomicilio.txt', sep='|', index=False)
m_dispersiones.to_csv('DM_DatosDispersion.txt', sep='|', index=False)
m_demograficos.to_csv('DM_DatosGenerales.txt', sep='|', index=False)

# %%
#FI_PAISCU	FI_CANALCU	FI_SUCURSALCU	FI_FOLIOCU
marca_big.rename(columns={'#FI_ID_PAIS_CU':'FI_PAISCU','FI_ID_SUCURSAL_CU':'FI_SUCURSALCU','FI_ID_CANAL_CU':'FI_CANALCU','FI_FOLIO_CU':'FI_FOLIOCU'}, inplace=True)

# %%
marca_big
# Out:
#         FI_PAISCU FI_SUCURSALCU FI_CANALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0              -9         -5644          1       3323                    0
# 1              -1           172         20      24400                    0
# 2               1           100          1         87                   14
# 3               1           100          1        192                    4
# 4               1           100          1        239                   10
# ...           ...           ...        ...        ...                  ...
# 1866302         1          7566          1      65859                    4
# 1866303         1          6023          1      86678                    4
# 1866304         1          5667          1      27704                    4
# 1866305         1          9376          1       2917                    4
# 1866306         1          5572         39      25027                    4
#
#         FI_MARCA
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 1866302        1
# 1866303        1
# 1866304        1
# 1866305        1
# 1866306        1
#
# [1866307 rows x 6 columns]

# %%
marca_big = marca_big[['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU','FI_COD_IDENTIFICADOR','FI_MARCA']]

# %%
marca_big
# Out:
#         FI_PAISCU FI_CANALCU FI_SUCURSALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0              -9          1         -5644       3323                    0
# 1              -1         20           172      24400                    0
# 2               1          1           100         87                   14
# 3               1          1           100        192                    4
# 4               1          1           100        239                   10
# ...           ...        ...           ...        ...                  ...
# 1866302         1          1          7566      65859                    4
# 1866303         1          1          6023      86678                    4
# 1866304         1          1          5667      27704                    4
# 1866305         1          1          9376       2917                    4
# 1866306         1         39          5572      25027                    4
#
#         FI_MARCA
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 1866302        1
# 1866303        1
# 1866304        1
# 1866305        1
# 1866306        1
#
# [1866307 rows x 6 columns]

# %%
marca_big.merge(m_demograficos, on=['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU'])
# Out:
#     FI_PAISCU FI_CANALCU FI_SUCURSALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0           1          1           107      21953                   11
# 1           1          1           107      22197                   15
# 2           1          1           107      23497                   10
# 3           1          1           107      25223                    4
# 4           1          1           107      33467                   11
# ..        ...        ...           ...        ...                  ...
# 995         1          1          5673      38883                    4
# 996         1          1          4614      11725                    4
# 997         1          1          2164      53381                    4
# 998         1          1          2516     112089                    4
# 999         1          1          7977      82251                    4
#
#     FI_MARCA #FI_ID_INSTITUCION FI_EMPLEADO  \
# 0          1               4673     2009843
# 1          1               4673     2045275
# 2          1               6673      866620
# 3          1               5383     1875898
# 4          1               4673      704671
# ..       ...                ...         ...
# 995        1               5383     2742333
# 996        1               5383     2680757
# 997        1               5383     2718180
# 998        1               5383     2743048
# 999        1               5383     2718996
#
#                                         FC_INSTITUCION  \
# 0                                     IMSS PENSIONADOS
# 1                                     IMSS PENSIONADOS
# 2    GOBIERNO DE LA CIUDAD DE MEXICO ALCALDIA DE AZ...
# 3                              BAZ PORTABILIDAD NOMINA
# 4                                     IMSS PENSIONADOS
# ..                                                 ...
# 995                            BAZ PORTABILIDAD NOMINA
# 996                            BAZ PORTABILIDAD NOMINA
# 997                            BAZ PORTABILIDAD NOMINA
# 998                            BAZ PORTABILIDAD NOMINA
# 999                            BAZ PORTABILIDAD NOMINA
#
#                      FC_NOMBRECOMPLETO  ... FC_APELLIDO_PATERNO  \
# 0              RUBIET PALACIOS CABRERA  ...            PALACIOS
# 1              RODOLFO NORIA RODRIGUEZ  ...               NORIA
# 2           MARIA LUISA AGUAYO MORALES  ...              AGUAYO
# 3    MILDRET JOSEFINA AGUILAR GONZALEZ  ...             AGUILAR
# 4                CARLOS RAMIREZ ARROYO  ...             RAMIREZ
# ..                                 ...  ...                 ...
# 995           JOSE MANUEL PEÑA CORDOBA  ...                PEÑA
# 996         JUAN CARLOS CALIZ MARTINEZ  ...               CALIZ
# 997            ALFREDO SANTILLAN REYES  ...           SANTILLAN
# 998            MARCOS ARIEL SOLIS PECH  ...               SOLIS
# 999       JORDAN IMANOL POSADA MACEIRA  ...              POSADA
#
#     FC_APELLIDO_MATERNO FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO  \
# 0               CABRERA          1                  NaN                1
# 1             RODRIGUEZ          1                  NaN                1
# 2               MORALES          1  08/01/1999 00:00:00                1
# 3              GONZALEZ          1  09/24/2020 00:00:00                1
# 4                ARROYO          1                  NaN                1
# ..                  ...        ...                  ...              ...
# 995             CORDOBA          1  08/27/2021 18:15:12                1
# 996            MARTINEZ          1  07/31/2021 16:42:33                1
# 997               REYES          1  08/14/2021 13:41:24                1
# 998                PECH          1  08/28/2021 16:05:37                1
# 999             MACEIRA          1  08/15/2021 18:09:02                1
#
#     FNEDONACIMIENTO FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 0                 9             2             7      1            484
# 1                15             2             7      2            484
# 2                 9             1             3      1            484
# 3                21             1             7      1            484
# 4                15             2             7      2            484
# ..              ...           ...           ...    ...            ...
# 995              30             0             7      2            484
# 996              15             1             7      2            484
# 997              15             0             7      2            484
# 998               4             0             7      2            484
# 999               5             0             7      2            484
#
# [1000 rows x 44 columns]

# %%
m_marca_big = marca_big.merge(m_demograficos, on=['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU'])

# %%
m_marca_big = m_marca_big[['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU','FI_COD_IDENTIFICADOR','FI_MARCA']]

# %%
m_marca_big
# Out:
#     FI_PAISCU FI_CANALCU FI_SUCURSALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0           1          1           107      21953                   11
# 1           1          1           107      22197                   15
# 2           1          1           107      23497                   10
# 3           1          1           107      25223                    4
# 4           1          1           107      33467                   11
# ..        ...        ...           ...        ...                  ...
# 995         1          1          5673      38883                    4
# 996         1          1          4614      11725                    4
# 997         1          1          2164      53381                    4
# 998         1          1          2516     112089                    4
# 999         1          1          7977      82251                    4
#
#     FI_MARCA
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 995        1
# 996        1
# 997        1
# 998        1
# 999        1
#
# [1000 rows x 6 columns]

# %%
m_marca_big.to_csv('Marca_BIG.txt', sep='|', index=False)
