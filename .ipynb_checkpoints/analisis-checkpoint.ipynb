# %%
import numpy as np
import pandas as pd

# %%
# Carga de archivos
demograficos = pd.read_csv('/Volumes/demograficos/DM_DatosGenerales.txt', delimiter='|', encoding='latin1', header=0, dtype=object)
dispersiones = pd.read_csv('/Volumes/demograficos/DM_DatosDispersion.txt', delimiter='|', encoding='latin1', header=0, dtype=object)
domicilios = pd.read_csv('/Volumes/demograficos/DM_DatosDomicilio.txt', delimiter='|', encoding='latin1', header=0, dtype=object)
marca_big = pd.read_csv('/Volumes/demograficos/Marca_BIG.txt', delimiter='|', encoding='latin1', header=0, dtype=object)

# %%
demograficos
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 0                    11098     3432009         1          9          2767
# 1                      473     3478305         1          1          4747
# 2                     5914     3460092         1          1           181
# 3                     5383     3520448         1          1          6897
# 4                    11527     3511538         1          1          5908
# ...                    ...         ...       ...        ...           ...
# 2219943               3469      633726         1          1          2218
# 2219944               5518      658481         1         10           766
# 2219945               6294      677746         1          1          7284
# 2219946               5383      699727         1          1          4527
# 2219947               5386      721509         1          1          2697
#
#         FI_FOLIOCU                                     FC_INSTITUCION  \
# 0              626                                              BECAS
# 1            20740                BRAME COMUNICACION DIGITAL SA DE CV
# 2            64393              SERVICIO COMERCIAL GARIS S.A. DE C.V.
# 3            80741                            BAZ PORTABILIDAD NOMINA
# 4            74921                           ASEADITO S DE R L DE C V
# ...            ...                                                ...
# 2219943      30387  PROFESIONALES EN MANTENIMIENTO Y LIMPIEZA SA D...
# 2219944       1245    REPRESENTACIONES DEL SURESTE DE MEXICO SA DE CV
# 2219945      11729  SINEMEN SIND TRAB IND GRAL DIST PROD EMB ENV S...
# 2219946     120895                            BAZ PORTABILIDAD NOMINA
# 2219947      26838                                 LIMPORIUM SA DE CV
#
#                           FC_NOMBRECOMPLETO   FD_FECHANACIMIENTO  \
# 0                 JOSE MIGUEL CORTES MENDEZ  12/01/1996 00:00:00
# 1                  JOSE ANGEL ROSAS ALVAREZ  08/14/1983 00:00:00
# 2          MARIA DEL CARMEN PEREZ TOLENTINO  02/08/1991 00:00:00
# 3             DAFNE ISELA MONTESINO AGUILAR  08/16/2000 00:00:00
# 4                         ALONSO BRUNO CRUZ  01/23/1979 00:00:00
# ...                                     ...                  ...
# 2219943            REGINO SALGADO DOMINGUEZ  03/12/1965 00:00:00
# 2219944            JOSE ANASTASIO TUN PEREZ  07/26/1975 00:00:00
# 2219945               ALEXA MCDONALD COTERO  08/06/1997 00:00:00
# 2219946             ORLANDO SOLIS ALEJANDRO  08/11/1993 12:00:00
# 2219947  MARIA JUANA FELIPA RICARDO BAROJAS  03/26/1969 00:00:00
#
#         FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO FC_APELLIDO_MATERNO  \
# 0                     NaN  ...              CORTES              MENDEZ
# 1                     NaN  ...               ROSAS             ALVAREZ
# 2                     NaN  ...               PEREZ           TOLENTINO
# 3                     NaN  ...           MONTESINO             AGUILAR
# 4                     NaN  ...               BRUNO                CRUZ
# ...                   ...  ...                 ...                 ...
# 2219943               NaN  ...             SALGADO           DOMINGUEZ
# 2219944               NaN  ...                 TUN               PEREZ
# 2219945               NaN  ...            MCDONALD              COTERO
# 2219946               NaN  ...               SOLIS           ALEJANDRO
# 2219947               NaN  ...             RICARDO             BAROJAS
#
#         FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO  \
# 0                1  10/31/2020 00:00:00                1               7
# 1                1                  NaN                1               9
# 2                1                  NaN                1              15
# 3                1  11/15/2021 18:39:41                1              23
# 4                1                  NaN                1               7
# ...            ...                  ...              ...             ...
# 2219943          1                  NaN                1              11
# 2219944          1                  NaN                1              31
# 2219945          1                  NaN                1               9
# 2219946          1                  NaN                1              17
# 2219947          1                  NaN                1             NaN
#
#         FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 0                   0             7      2            484
# 1                   1             7      2            484
# 2                   1             7      1            484
# 3                   0             7      1            484
# 4                   2             7      2            484
# ...               ...           ...    ...            ...
# 2219943             2             7      2            484
# 2219944             1             7      2            484
# 2219945             1             7      1            484
# 2219946             4             7      2            484
# 2219947             0           NaN      1            484
#
# [2219948 rows x 42 columns]

# %%
dispersiones['FN_SALARIO'] = dispersiones['FN_SALARIO'].astype(float)

# %%
dispersiones['FIPERIODICIDADPAGO'] = pd.to_numeric(dispersiones['FIPERIODICIDADPAGO'], errors='coerce')

# %%
dispersiones = dispersiones.dropna(subset=['FIPERIODICIDADPAGO'])

# %%
dispersiones = dispersiones.dropna(subset=['FI_TOTALDISPER'])

# %%
dispersiones['FIPERIODICIDADPAGO'] = dispersiones['FIPERIODICIDADPAGO'].astype(int)
# Out:
# /var/folders/p_/d1ty51193js_k1md1xwnzd300000gn/T/ipykernel_7302/1488484356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dispersiones['FIPERIODICIDADPAGO'] = dispersiones['FIPERIODICIDADPAGO'].astype(int)

# %%
dispersiones['FI_TOTALDISPER'] = dispersiones['FI_TOTALDISPER'].astype(int)

# %%
dispersiones = dispersiones[dispersiones['FN_SALARIO'] > 0]

# %%
dispersiones['FIPERIODICIDADPAGO'] = dispersiones['FIPERIODICIDADPAGO'].astype(int)
# Out:
# /var/folders/p_/d1ty51193js_k1md1xwnzd300000gn/T/ipykernel_7302/1488484356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dispersiones['FIPERIODICIDADPAGO'] = dispersiones['FIPERIODICIDADPAGO'].astype(int)

# %%
dispersiones
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO             FC_CUENTA  \
# 0                     4673      244856  01277645780106410150
# 2                     4673      244860  01272080260173736647
# 3                     4673      244861  01271701210198832030
# 8                     4673      244875  01274132260176358222
# 9                     4673      244877  01276813130104919555
# ...                    ...         ...                   ...
# 2222397               6633     3411046  01272202021360380941
# 2222403               5383     3407340  01279546161629544615
# 2222406               5383     3381046  01270364300162484332
# 2222410               5383     3407575  01276186060114666353
# 2222415              11004     3415949  01272216680163003291
#
#              FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 0        11/30/2021 00:00:00               7     2965.15             MENSUAL
# 2        11/30/2021 00:00:00               7     3054.92             MENSUAL
# 3        11/30/2021 00:00:00               7     2953.39             MENSUAL
# 8        11/30/2021 00:00:00               7      616.57             MENSUAL
# 9        11/30/2021 00:00:00               7     1896.22             MENSUAL
# ...                      ...             ...         ...                 ...
# 2222397  12/09/2021 00:00:00              20     1343.83             SEMANAL
# 2222403  12/09/2021 00:00:00               4    55541.65           QUINCENAL
# 2222406  12/09/2021 00:00:00              10     1740.27             SEMANAL
# 2222410  12/10/2021 00:00:00               6     2084.36             SEMANAL
# 2222415  11/25/2021 00:00:00               6      887.45             SEMANAL
#
#         FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 0                    NaN            PENSIONADOS Y JUBILADOS             11
# 2                    NaN            PENSIONADOS Y JUBILADOS             11
# 3                    NaN            PENSIONADOS Y JUBILADOS             11
# 8                    NaN            PENSIONADOS Y JUBILADOS             11
# 9                    NaN            PENSIONADOS Y JUBILADOS             11
# ...                  ...                                ...            ...
# 2222397              NaN                      NOMINA AZTECA             10
# 2222403              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 2222406              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 2222410              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 2222415              NaN                      NOMINA AZTECA             10
#
#         FI_CREDITOSACTIV  FIPERIODICIDADPAGO FI_CTA_DIGITOS
# 0                      3                   3      106410150
# 2                      0                   3      173736647
# 3                      0                   3      198832030
# 8                      1                   3      176358222
# 9                      3                   3      104919555
# ...                  ...                 ...            ...
# 2222397                0                   1     1360380941
# 2222403                0                   2     1629544615
# 2222406                0                   1      162484332
# 2222410                0                   1      114666353
# 2222415                0                   1      163003291
#
# [618935 rows x 13 columns]

# %%
empleados_muestra = dispersiones.sample(n=100000)

# %%
domicilios = domicilios.dropna(subset=['FC_LATITUD'])

# %%
domicilios = domicilios.dropna(subset=['FC_ID_ESTADO'])

# %%
domicilios = domicilios.dropna(subset=['FI_ID_MUNICIPIO'])

# %%
domicilios
# Out:
#         #FI_ID_INSTITUCION FI_EMPLEADO     FC_CALLEHOGAR FC_NUMEXTHOGAR  \
# 13                    4673        1273           TIZAPAN          MZ318
# 14                    4673      175482        SAN ISIDRO              2
# 15                    4673      182599      VENINTINUEVE            168
# 16                    4673      190654            VARGAS             SN
# 17                    4673      194835        SANTA ROSA             90
# ...                    ...         ...               ...            ...
# 2219942               3469      575518  4 ORIENTE JUAREZ            928
# 2219945               3469      619807   PROL ALTAMIRANO            929
# 2219948               6148      627277  MIGUEL DOMINGUEZ             35
# 2219949               5383      646082     NICOLAS BRAVO           1050
# 2219953               5383      699727        C PROGRESO             16
#
#         FC_NUMINTHOGAR           FC_COLONIAHOGAR    FC_MUNICIPIOHOGAR  \
# 13                 LT7             CIUDAD AZTECA               MEXICO
# 14                   0                SAN ISIDRO               MEXICO
# 15                 SIN          ESTADO DE MEXICO       NEZAHUALCOYOTL
# 16                  SN          VICENTE GUERRERO       NICOLAS ROMERO
# 17                 NaN              LA RAQUELITO            NAUCALPAN
# ...                ...                       ...                  ...
# 2219942            NaN                  LAFRAGUA             Lafragua
# 2219945            NaN               SALVATIERRA          Salvatierra
# 2219948            402  PENITENCIARIA AMPLIACION  VENUSTIANO CARRANZA
# 2219949            NaN       CONST DE APATZINGAN             Irapuato
# 2219953            NaN        Lomas de Guadalupe              Temixco
#
#            FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS FI_ID_TIPOVIVIENDA  \
# 13               ECATEPEC           55120  MEXICO                  3
# 14           CHIMALHUACAN           56330  MEXICO                  3
# 15                 MEXICO           57210  Mexico                  3
# 16                 MEXICO           54424  MEXICO                  3
# 17                 MEXICO           53660  Mexico                  3
# ...                   ...             ...     ...                ...
# 2219942            PUEBLA           73780  MEXICO                  3
# 2219945        GUANAJUATO           38900  MEXICO                  3
# 2219948  CIUDAD DE MEXICO           15350  Mexico                  3
# 2219949        GUANAJUATO           36589  MEXICO                  2
# 2219953           MORELOS           62583  MEXICO                  3
#
#         FC_ID_TIPOVIVIENDA           FC_LATITUD            FC_LONGITUD  \
# 13                  PROPIA  19.5443440000000000   -99.0294730000000000
# 14                  PROPIA  19.3984560000000000   -98.9199310000000000
# 15                  PROPIA  19.4230630000000000   -99.0445250000000000
# 16                  PROPIA  19.6104130000000000   -99.3258810000000000
# 17                  PROPIA  19.4568430000000000   -99.2694300000000000
# ...                    ...                  ...                    ...
# 2219942             PROPIA  19.4663030000000000   -97.6839890000000000
# 2219945             PROPIA  20.2086700000000000  -100.8790930000000000
# 2219948             PROPIA  19.4354940000000000   -99.1197130000000000
# 2219949           FAMILIAR  20.6903780000000000  -101.3111310000000000
# 2219953             PROPIA  18.8500350000000000   -99.2298850000000000
#
#         FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO FC_ID_ESTADO FI_ID_PAIS
# 13              NaN           NaN               1           15          1
# 14              NaN           NaN               6           15          1
# 15              NaN           NaN              58           15          1
# 16              NaN           NaN              60           15          1
# 17              NaN           NaN              57           15          1
# ...             ...           ...             ...          ...        ...
# 2219942         NaN           NaN              93           21          1
# 2219945         NaN           NaN              28           11          1
# 2219948         NaN           NaN              17            9          1
# 2219949         NaN           NaN              17           11          1
# 2219953         NaN           NaN              18           17          1
#
# [1059938 rows x 19 columns]

# %%
subset = dispersiones.merge(domicilios, on='FI_EMPLEADO')

# %%
test = dispersiones.merge(domicilios, on='FI_EMPLEADO').merge(demograficos, on='FI_EMPLEADO')

# %%
test = test.sample(n=100)

# %%
test
# Out:
#        #FI_ID_INSTITUCION_x FI_EMPLEADO             FC_CUENTA  \
# 296237                11879     2472450  01275670210120900051
# 211820                11126     1950396  01270180210127920948
# 44185                  4673      238986  01277090980176376170
# 107775                 5383     1065483  01277034300126590160
# 299035                11879     2461778  01272392110120972965
# ...                     ...         ...                   ...
# 120178                 5383     1190451  01276095120128509700
# 281332                 5383     2370562  01275647270154199432
# 131833                 5383     1307557  01279970050130659970
# 12705                  4673      177617  01271652130187177355
# 127901                 4673     1131903  01272435350127014289
#
#             FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 296237  12/09/2021 00:00:00              18     4916.76             SEMANAL
# 211820  12/09/2021 00:00:00              13     3072.11           QUINCENAL
# 44185   11/30/2021 00:00:00               7     5781.23             MENSUAL
# 107775  12/06/2021 00:00:00              21     2429.64           QUINCENAL
# 299035  12/09/2021 00:00:00              18     4884.24             SEMANAL
# ...                     ...             ...         ...                 ...
# 120178  12/10/2021 00:00:00              29     1291.24             SEMANAL
# 281332  11/16/2021 00:00:00               5     4310.00             MENSUAL
# 131833  11/29/2021 00:00:00              20     5094.78           QUINCENAL
# 12705   11/30/2021 00:00:00               7    10478.61             MENSUAL
# 127901  11/30/2021 00:00:00               7     3677.13             MENSUAL
#
#        FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 296237              NaN                      NOMINA AZTECA             10
# 211820              NaN                      NOMINA AZTECA             10
# 44185               NaN            PENSIONADOS Y JUBILADOS             11
# 107775              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 299035              NaN                      NOMINA AZTECA             10
# ...                 ...                                ...            ...
# 120178              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 281332              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 131833              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 12705               NaN            PENSIONADOS Y JUBILADOS             11
# 127901              NaN            PENSIONADOS Y JUBILADOS             11
#
#         ... FC_APELLIDO_PATERNO  FC_APELLIDO_MATERNO FI_ID_PAIS_y  \
# 296237  ...         VILLALPANDO                GOMEZ            1
# 211820  ...               ROJAS              JIMENEZ            1
# 44185   ...               OCHOA            HERNANDEZ            1
# 107775  ...              CORTES              BECERRA            1
# 299035  ...           GUTIERREZ               MONTER            1
# ...     ...                 ...                  ...          ...
# 120178  ...                POOT                  PUC            1
# 281332  ...               LOPEZ               GARCIA            1
# 131833  ...             RAMIREZ             BALTAZAR            1
# 12705   ...               BRAVO              ALVAREZ            1
# 127901  ...            ELIZALDE            HERNANDEZ            1
#
#               FD_FECHA_ALTA FNPAISNACIMIENTO FNEDONACIMIENTO FNESTADOCIVIL  \
# 296237  12/06/2020 00:00:00                1              11             2
# 211820  11/01/2019 00:00:00                1              20             2
# 44185   04/27/2007 00:00:00                1              28             5
# 107775  06/02/2019 12:00:00                1              14             1
# 299035  12/06/2020 00:00:00                1              13             2
# ...                     ...              ...             ...           ...
# 120178                  NaN                1              31             1
# 281332  12/05/2020 00:00:00                1              20             1
# 131833                  NaN                1              12             2
# 12705   03/28/2018 00:00:00                1              15             2
# 127901                  NaN                1               9             5
#
#        FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 296237             7      1            484
# 211820             7      2            484
# 44185              7      2            484
# 107775             7      2            484
# 299035             7      1            484
# ...              ...    ...            ...
# 120178             7      2            484
# 281332             7      2            484
# 131833             7      1            484
# 12705              7      2            484
# 127901             7      1            484
#
# [100 rows x 72 columns]

# %%
test.columns
# Out:
# Index(['#FI_ID_INSTITUCION_x', 'FI_EMPLEADO', 'FC_CUENTA', 'FD_ULTIMADISPER',
#        'FI_TOTALDISPER', 'FN_SALARIO', 'FC_PERIODICIDADPAGO',
#        'FI_CAPACIDADPAGO', 'FC_PRODUCTO', 'FI_ID_PRODUCTO', 'FI_CREDITOSACTIV',
#        'FIPERIODICIDADPAGO', 'FI_CTA_DIGITOS', '#FI_ID_INSTITUCION_y',
#        'FC_CALLEHOGAR', 'FC_NUMEXTHOGAR', 'FC_NUMINTHOGAR', 'FC_COLONIAHOGAR',
#        'FC_MUNICIPIOHOGAR', 'FC_ESTADOHOGAR', 'FC_CODIGOPOSTAL', 'FC_PAIS',
#        'FI_ID_TIPOVIVIENDA', 'FC_ID_TIPOVIVIENDA', 'FC_LATITUD', 'FC_LONGITUD',
#        'FC_SUCURSAL', 'FI_ID_COLONIA', 'FI_ID_MUNICIPIO', 'FC_ID_ESTADO',
#        'FI_ID_PAIS_x', '#FI_ID_INSTITUCION', 'FI_PAISCU', 'FI_CANALCU',
#        'FI_SUCURSALCU', 'FI_FOLIOCU', 'FC_INSTITUCION', 'FC_NOMBRECOMPLETO',
#        'FD_FECHANACIMIENTO', 'FC_PAISNACIMIENTO', 'FC_ESTADONACIMIENTO',
#        'FI_EDAD', 'FC_RFC', 'FC_CURP', 'FC_NSS', 'FC_ESTADOCIVIL',
#        'FC_ESCOLARIDAD', 'FC_SEXO', 'FC_TELEFONOCASA', 'FC_TELCELULAR',
#        'FC_EMAIL', 'FC_AVISOPRIVACIDAD', 'FC_CONSULTABURO',
#        'FC_USODATOSPERSONA', 'FC_USODATOSPROMO', 'FC_NACIONALIDAD',
#        'FD_ALTAEMPLEADO', 'FI_DATOS_CORRECTOS', 'FI_OFERTA', 'FC_STATUS_EMP',
#        'FI_STATUS_EMP', 'FC_NOMBRE_EMPLEADO', 'FC_APELLIDO_PATERNO',
#        'FC_APELLIDO_MATERNO', 'FI_ID_PAIS_y', 'FD_FECHA_ALTA',
#        'FNPAISNACIMIENTO', 'FNEDONACIMIENTO', 'FNESTADOCIVIL', 'FNESCOLARIDAD',
#        'FNSEXO', 'FNNACIONALIDAD'],
#       dtype='object')

# %%
m_demograficos = test[['#FI_ID_INSTITUCION', 'FI_EMPLEADO', 'FI_PAISCU', 'FI_CANALCU',
       'FI_SUCURSALCU', 'FI_FOLIOCU', 'FC_INSTITUCION', 'FC_NOMBRECOMPLETO',
       'FD_FECHANACIMIENTO', 'FC_PAISNACIMIENTO', 'FC_ESTADONACIMIENTO',
       'FI_EDAD', 'FC_RFC', 'FC_CURP', 'FC_NSS', 'FC_ESTADOCIVIL',
       'FC_ESCOLARIDAD', 'FC_SEXO', 'FC_TELEFONOCASA', 'FC_TELCELULAR',
       'FC_EMAIL', 'FC_AVISOPRIVACIDAD', 'FC_CONSULTABURO',
       'FC_USODATOSPERSONA', 'FC_USODATOSPROMO', 'FC_NACIONALIDAD',
       'FD_ALTAEMPLEADO', 'FI_DATOS_CORRECTOS', 'FI_OFERTA', 'FC_STATUS_EMP',
       'FI_STATUS_EMP', 'FC_NOMBRE_EMPLEADO', 'FC_APELLIDO_PATERNO',
       'FC_APELLIDO_MATERNO', 'FI_ID_PAIS_y', 'FD_FECHA_ALTA',
       'FNPAISNACIMIENTO', 'FNEDONACIMIENTO', 'FNESTADOCIVIL', 'FNESCOLARIDAD',
       'FNSEXO', 'FNNACIONALIDAD']]

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 296237              11879     2472450         1          9          5670
# 211820              11126     1950396         1          1           218
# 44185                4673      238986         1          1          7090
# 107775               5383     1065483         1          1          7034
# 299035              11879     2461778         1          1          2392
# ...                   ...         ...       ...        ...           ...
# 120178               5383     1190451         1          1          6095
# 281332               5383     2370562         1          1          2684
# 131833               5383     1307557         1          1          2079
# 12705                4673      177617         1         20          1652
# 127901               4673     1131903         1          1          2435
#
#        FI_FOLIOCU           FC_INSTITUCION                FC_NOMBRECOMPLETO  \
# 296237       4118   CUTSPEI SIN CLASIFICAR      MARGARITA VILLALPANDO GOMEZ
# 211820       3230                TESOFE 11  RICARDO FRANCISCO ROJAS JIMENEZ
# 44185       16570         IMSS PENSIONADOS        J VICENTE OCHOA HERNANDEZ
# 107775     129701  BAZ PORTABILIDAD NOMINA  ANTONIO DE JESUS CORTES BECERRA
# 299035      51112   CUTSPEI SIN CLASIFICAR       ESMERALDA GUTIERREZ MONTER
# ...           ...                      ...                              ...
# 120178      20096  BAZ PORTABILIDAD NOMINA            SANTOS EDGAR POOT PUC
# 281332     126026  BAZ PORTABILIDAD NOMINA        LUIS ARMANDO LOPEZ GARCIA
# 131833      81623  BAZ PORTABILIDAD NOMINA           ADINA RAMIREZ BALTAZAR
# 12705        4245         IMSS PENSIONADOS            EDUARDO BRAVO ALVAREZ
# 127901      75870         IMSS PENSIONADOS         LAURA ELIZALDE HERNANDEZ
#
#          FD_FECHANACIMIENTO FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO  \
# 296237  11/01/1950 00:00:00               NaN  ...         VILLALPANDO
# 211820  12/04/1973 00:00:00               NaN  ...               ROJAS
# 44185   02/01/1947 00:00:00            MEXICO  ...               OCHOA
# 107775  07/06/2001 00:00:00               NaN  ...              CORTES
# 299035  12/02/1993 00:00:00               NaN  ...           GUTIERREZ
# ...                     ...               ...  ...                 ...
# 120178  03/03/1993 12:00:00               NaN  ...                POOT
# 281332  01/13/1998 00:00:00               NaN  ...               LOPEZ
# 131833  04/23/1986 00:00:00               NaN  ...             RAMIREZ
# 12705   09/30/1940 00:00:00            MEXICO  ...               BRAVO
# 127901  03/19/1958 12:00:00               NaN  ...            ELIZALDE
#
#        FC_APELLIDO_MATERNO FI_ID_PAIS_y        FD_FECHA_ALTA FNPAISNACIMIENTO  \
# 296237               GOMEZ            1  12/06/2020 00:00:00                1
# 211820             JIMENEZ            1  11/01/2019 00:00:00                1
# 44185            HERNANDEZ            1  04/27/2007 00:00:00                1
# 107775             BECERRA            1  06/02/2019 12:00:00                1
# 299035              MONTER            1  12/06/2020 00:00:00                1
# ...                    ...          ...                  ...              ...
# 120178                 PUC            1                  NaN                1
# 281332              GARCIA            1  12/05/2020 00:00:00                1
# 131833            BALTAZAR            1                  NaN                1
# 12705              ALVAREZ            1  03/28/2018 00:00:00                1
# 127901           HERNANDEZ            1                  NaN                1
#
#        FNEDONACIMIENTO FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 296237              11             2             7      1            484
# 211820              20             2             7      2            484
# 44185               28             5             7      2            484
# 107775              14             1             7      2            484
# 299035              13             2             7      1            484
# ...                ...           ...           ...    ...            ...
# 120178              31             1             7      2            484
# 281332              20             1             7      2            484
# 131833              12             2             7      1            484
# 12705               15             2             7      2            484
# 127901               9             5             7      1            484
#
# [100 rows x 42 columns]

# %%
m_dispersiones = test[['#FI_ID_INSTITUCION_x', 'FI_EMPLEADO', 'FC_CUENTA', 'FD_ULTIMADISPER',
       'FI_TOTALDISPER', 'FN_SALARIO', 'FC_PERIODICIDADPAGO',
       'FI_CAPACIDADPAGO', 'FC_PRODUCTO', 'FI_ID_PRODUCTO', 'FI_CREDITOSACTIV',
       'FIPERIODICIDADPAGO', 'FI_CTA_DIGITOS']]

# %%
m_dispersiones
# Out:
#        #FI_ID_INSTITUCION_x FI_EMPLEADO             FC_CUENTA  \
# 296237                11879     2472450  01275670210120900051
# 211820                11126     1950396  01270180210127920948
# 44185                  4673      238986  01277090980176376170
# 107775                 5383     1065483  01277034300126590160
# 299035                11879     2461778  01272392110120972965
# ...                     ...         ...                   ...
# 120178                 5383     1190451  01276095120128509700
# 281332                 5383     2370562  01275647270154199432
# 131833                 5383     1307557  01279970050130659970
# 12705                  4673      177617  01271652130187177355
# 127901                 4673     1131903  01272435350127014289
#
#             FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 296237  12/09/2021 00:00:00              18     4916.76             SEMANAL
# 211820  12/09/2021 00:00:00              13     3072.11           QUINCENAL
# 44185   11/30/2021 00:00:00               7     5781.23             MENSUAL
# 107775  12/06/2021 00:00:00              21     2429.64           QUINCENAL
# 299035  12/09/2021 00:00:00              18     4884.24             SEMANAL
# ...                     ...             ...         ...                 ...
# 120178  12/10/2021 00:00:00              29     1291.24             SEMANAL
# 281332  11/16/2021 00:00:00               5     4310.00             MENSUAL
# 131833  11/29/2021 00:00:00              20     5094.78           QUINCENAL
# 12705   11/30/2021 00:00:00               7    10478.61             MENSUAL
# 127901  11/30/2021 00:00:00               7     3677.13             MENSUAL
#
#        FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 296237              NaN                      NOMINA AZTECA             10
# 211820              NaN                      NOMINA AZTECA             10
# 44185               NaN            PENSIONADOS Y JUBILADOS             11
# 107775              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 299035              NaN                      NOMINA AZTECA             10
# ...                 ...                                ...            ...
# 120178              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 281332              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 131833              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 12705               NaN            PENSIONADOS Y JUBILADOS             11
# 127901              NaN            PENSIONADOS Y JUBILADOS             11
#
#        FI_CREDITOSACTIV  FIPERIODICIDADPAGO FI_CTA_DIGITOS
# 296237                0                   1      120900051
# 211820                0                   2      127920948
# 44185                 0                   3      176376170
# 107775                2                   2      126590160
# 299035                0                   1      120972965
# ...                 ...                 ...            ...
# 120178                0                   1      128509700
# 281332                0                   3      154199432
# 131833                1                   2      130659970
# 12705                 0                   3      187177355
# 127901                0                   3      127014289
#
# [100 rows x 13 columns]

# %%
m_domicilios = test[['#FI_ID_INSTITUCION_y', 'FI_EMPLEADO',
       'FC_CALLEHOGAR', 'FC_NUMEXTHOGAR', 'FC_NUMINTHOGAR', 'FC_COLONIAHOGAR',
       'FC_MUNICIPIOHOGAR', 'FC_ESTADOHOGAR', 'FC_CODIGOPOSTAL', 'FC_PAIS',
       'FI_ID_TIPOVIVIENDA', 'FC_ID_TIPOVIVIENDA', 'FC_LATITUD', 'FC_LONGITUD',
       'FC_SUCURSAL', 'FI_ID_COLONIA', 'FI_ID_MUNICIPIO', 'FC_ID_ESTADO',
       'FI_ID_PAIS_x']]

# %%
m_demograficos.columns
# Out:
# Index(['#FI_ID_INSTITUCION', 'FI_EMPLEADO', 'FI_PAISCU', 'FI_CANALCU',
#        'FI_SUCURSALCU', 'FI_FOLIOCU', 'FC_INSTITUCION', 'FC_NOMBRECOMPLETO',
#        'FD_FECHANACIMIENTO', 'FC_PAISNACIMIENTO', 'FC_ESTADONACIMIENTO',
#        'FI_EDAD', 'FC_RFC', 'FC_CURP', 'FC_NSS', 'FC_ESTADOCIVIL',
#        'FC_ESCOLARIDAD', 'FC_SEXO', 'FC_TELEFONOCASA', 'FC_TELCELULAR',
#        'FC_EMAIL', 'FC_AVISOPRIVACIDAD', 'FC_CONSULTABURO',
#        'FC_USODATOSPERSONA', 'FC_USODATOSPROMO', 'FC_NACIONALIDAD',
#        'FD_ALTAEMPLEADO', 'FI_DATOS_CORRECTOS', 'FI_OFERTA', 'FC_STATUS_EMP',
#        'FI_STATUS_EMP', 'FC_NOMBRE_EMPLEADO', 'FC_APELLIDO_PATERNO',
#        'FC_APELLIDO_MATERNO', 'FI_ID_PAIS_y', 'FD_FECHA_ALTA',
#        'FNPAISNACIMIENTO', 'FNEDONACIMIENTO', 'FNESTADOCIVIL', 'FNESCOLARIDAD',
#        'FNSEXO', 'FNNACIONALIDAD'],
#       dtype='object')

# %%
m_demograficos.rename(columns={'FI_ID_PAIS_y':'FI_ID_PAIS'}, inplace=True)
# Out:
# /Users/ilucash/Documents/Proyectos/BIG/NAC/venv/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 296237              11879     2472450         1          9          5670
# 211820              11126     1950396         1          1           218
# 44185                4673      238986         1          1          7090
# 107775               5383     1065483         1          1          7034
# 299035              11879     2461778         1          1          2392
# ...                   ...         ...       ...        ...           ...
# 120178               5383     1190451         1          1          6095
# 281332               5383     2370562         1          1          2684
# 131833               5383     1307557         1          1          2079
# 12705                4673      177617         1         20          1652
# 127901               4673     1131903         1          1          2435
#
#        FI_FOLIOCU           FC_INSTITUCION                FC_NOMBRECOMPLETO  \
# 296237       4118   CUTSPEI SIN CLASIFICAR      MARGARITA VILLALPANDO GOMEZ
# 211820       3230                TESOFE 11  RICARDO FRANCISCO ROJAS JIMENEZ
# 44185       16570         IMSS PENSIONADOS        J VICENTE OCHOA HERNANDEZ
# 107775     129701  BAZ PORTABILIDAD NOMINA  ANTONIO DE JESUS CORTES BECERRA
# 299035      51112   CUTSPEI SIN CLASIFICAR       ESMERALDA GUTIERREZ MONTER
# ...           ...                      ...                              ...
# 120178      20096  BAZ PORTABILIDAD NOMINA            SANTOS EDGAR POOT PUC
# 281332     126026  BAZ PORTABILIDAD NOMINA        LUIS ARMANDO LOPEZ GARCIA
# 131833      81623  BAZ PORTABILIDAD NOMINA           ADINA RAMIREZ BALTAZAR
# 12705        4245         IMSS PENSIONADOS            EDUARDO BRAVO ALVAREZ
# 127901      75870         IMSS PENSIONADOS         LAURA ELIZALDE HERNANDEZ
#
#          FD_FECHANACIMIENTO FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO  \
# 296237  11/01/1950 00:00:00               NaN  ...         VILLALPANDO
# 211820  12/04/1973 00:00:00               NaN  ...               ROJAS
# 44185   02/01/1947 00:00:00            MEXICO  ...               OCHOA
# 107775  07/06/2001 00:00:00               NaN  ...              CORTES
# 299035  12/02/1993 00:00:00               NaN  ...           GUTIERREZ
# ...                     ...               ...  ...                 ...
# 120178  03/03/1993 12:00:00               NaN  ...                POOT
# 281332  01/13/1998 00:00:00               NaN  ...               LOPEZ
# 131833  04/23/1986 00:00:00               NaN  ...             RAMIREZ
# 12705   09/30/1940 00:00:00            MEXICO  ...               BRAVO
# 127901  03/19/1958 12:00:00               NaN  ...            ELIZALDE
#
#        FC_APELLIDO_MATERNO FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO  \
# 296237               GOMEZ          1  12/06/2020 00:00:00                1
# 211820             JIMENEZ          1  11/01/2019 00:00:00                1
# 44185            HERNANDEZ          1  04/27/2007 00:00:00                1
# 107775             BECERRA          1  06/02/2019 12:00:00                1
# 299035              MONTER          1  12/06/2020 00:00:00                1
# ...                    ...        ...                  ...              ...
# 120178                 PUC          1                  NaN                1
# 281332              GARCIA          1  12/05/2020 00:00:00                1
# 131833            BALTAZAR          1                  NaN                1
# 12705              ALVAREZ          1  03/28/2018 00:00:00                1
# 127901           HERNANDEZ          1                  NaN                1
#
#        FNEDONACIMIENTO FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 296237              11             2             7      1            484
# 211820              20             2             7      2            484
# 44185               28             5             7      2            484
# 107775              14             1             7      2            484
# 299035              13             2             7      1            484
# ...                ...           ...           ...    ...            ...
# 120178              31             1             7      2            484
# 281332              20             1             7      2            484
# 131833              12             2             7      1            484
# 12705               15             2             7      2            484
# 127901               9             5             7      1            484
#
# [100 rows x 42 columns]

# %%
m_dispersiones.columns
# Out:
# Index(['#FI_ID_INSTITUCION_x', 'FI_EMPLEADO', 'FC_CUENTA', 'FD_ULTIMADISPER',
#        'FI_TOTALDISPER', 'FN_SALARIO', 'FC_PERIODICIDADPAGO',
#        'FI_CAPACIDADPAGO', 'FC_PRODUCTO', 'FI_ID_PRODUCTO', 'FI_CREDITOSACTIV',
#        'FIPERIODICIDADPAGO', 'FI_CTA_DIGITOS'],
#       dtype='object')

# %%
m_dispersiones.rename(columns={'#FI_ID_INSTITUCION_x':'#FI_ID_INSTITUCION'}, inplace=True)
# Out:
# /Users/ilucash/Documents/Proyectos/BIG/NAC/venv/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 296237              11879     2472450         1          9          5670
# 211820              11126     1950396         1          1           218
# 44185                4673      238986         1          1          7090
# 107775               5383     1065483         1          1          7034
# 299035              11879     2461778         1          1          2392
# ...                   ...         ...       ...        ...           ...
# 120178               5383     1190451         1          1          6095
# 281332               5383     2370562         1          1          2684
# 131833               5383     1307557         1          1          2079
# 12705                4673      177617         1         20          1652
# 127901               4673     1131903         1          1          2435
#
#        FI_FOLIOCU           FC_INSTITUCION                FC_NOMBRECOMPLETO  \
# 296237       4118   CUTSPEI SIN CLASIFICAR      MARGARITA VILLALPANDO GOMEZ
# 211820       3230                TESOFE 11  RICARDO FRANCISCO ROJAS JIMENEZ
# 44185       16570         IMSS PENSIONADOS        J VICENTE OCHOA HERNANDEZ
# 107775     129701  BAZ PORTABILIDAD NOMINA  ANTONIO DE JESUS CORTES BECERRA
# 299035      51112   CUTSPEI SIN CLASIFICAR       ESMERALDA GUTIERREZ MONTER
# ...           ...                      ...                              ...
# 120178      20096  BAZ PORTABILIDAD NOMINA            SANTOS EDGAR POOT PUC
# 281332     126026  BAZ PORTABILIDAD NOMINA        LUIS ARMANDO LOPEZ GARCIA
# 131833      81623  BAZ PORTABILIDAD NOMINA           ADINA RAMIREZ BALTAZAR
# 12705        4245         IMSS PENSIONADOS            EDUARDO BRAVO ALVAREZ
# 127901      75870         IMSS PENSIONADOS         LAURA ELIZALDE HERNANDEZ
#
#          FD_FECHANACIMIENTO FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO  \
# 296237  11/01/1950 00:00:00               NaN  ...         VILLALPANDO
# 211820  12/04/1973 00:00:00               NaN  ...               ROJAS
# 44185   02/01/1947 00:00:00            MEXICO  ...               OCHOA
# 107775  07/06/2001 00:00:00               NaN  ...              CORTES
# 299035  12/02/1993 00:00:00               NaN  ...           GUTIERREZ
# ...                     ...               ...  ...                 ...
# 120178  03/03/1993 12:00:00               NaN  ...                POOT
# 281332  01/13/1998 00:00:00               NaN  ...               LOPEZ
# 131833  04/23/1986 00:00:00               NaN  ...             RAMIREZ
# 12705   09/30/1940 00:00:00            MEXICO  ...               BRAVO
# 127901  03/19/1958 12:00:00               NaN  ...            ELIZALDE
#
#        FC_APELLIDO_MATERNO FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO  \
# 296237               GOMEZ          1  12/06/2020 00:00:00                1
# 211820             JIMENEZ          1  11/01/2019 00:00:00                1
# 44185            HERNANDEZ          1  04/27/2007 00:00:00                1
# 107775             BECERRA          1  06/02/2019 12:00:00                1
# 299035              MONTER          1  12/06/2020 00:00:00                1
# ...                    ...        ...                  ...              ...
# 120178                 PUC          1                  NaN                1
# 281332              GARCIA          1  12/05/2020 00:00:00                1
# 131833            BALTAZAR          1                  NaN                1
# 12705              ALVAREZ          1  03/28/2018 00:00:00                1
# 127901           HERNANDEZ          1                  NaN                1
#
#        FNEDONACIMIENTO FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 296237              11             2             7      1            484
# 211820              20             2             7      2            484
# 44185               28             5             7      2            484
# 107775              14             1             7      2            484
# 299035              13             2             7      1            484
# ...                ...           ...           ...    ...            ...
# 120178              31             1             7      2            484
# 281332              20             1             7      2            484
# 131833              12             2             7      1            484
# 12705               15             2             7      2            484
# 127901               9             5             7      1            484
#
# [100 rows x 42 columns]

# %%
m_domicilios.columns
# Out:
# Index(['#FI_ID_INSTITUCION_y', 'FI_EMPLEADO', 'FC_CALLEHOGAR',
#        'FC_NUMEXTHOGAR', 'FC_NUMINTHOGAR', 'FC_COLONIAHOGAR',
#        'FC_MUNICIPIOHOGAR', 'FC_ESTADOHOGAR', 'FC_CODIGOPOSTAL', 'FC_PAIS',
#        'FI_ID_TIPOVIVIENDA', 'FC_ID_TIPOVIVIENDA', 'FC_LATITUD', 'FC_LONGITUD',
#        'FC_SUCURSAL', 'FI_ID_COLONIA', 'FI_ID_MUNICIPIO', 'FC_ID_ESTADO',
#        'FI_ID_PAIS_x'],
#       dtype='object')

# %%
m_domicilios.rename(columns={'#FI_ID_INSTITUCION_y':'#FI_ID_INSTITUCION','FI_ID_PAIS_x':'FI_ID_PAIS'}, inplace=True)
# Out:
# /Users/ilucash/Documents/Proyectos/BIG/NAC/venv/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
m_domicilios
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO              FC_CALLEHOGAR  \
# 296237              11879     2472450             PRIV LA FUENTE
# 211820              11126     1950396                   RIO SECO
# 44185                4673      238986         AVENIDA CONTADORES
# 107775               5383     1065483                   RIO TULA
# 299035              11879     2461778  PRIV REAL DE SAN FRANCISC
# ...                   ...         ...                        ...
# 120178               5383     1190451                          3
# 281332               5383     2370562                    GALEANA
# 131833               5383     1307557            BAJA CALIFORNIA
# 12705                4673      177617                  MZ L LT 1
# 127901               4673     1131903        2DO CJON TLAPECHICO
#
#        FC_NUMEXTHOGAR FC_NUMINTHOGAR                FC_COLONIAHOGAR  \
# 296237            118            NaN              PARQUE MANZANARES
# 211820              3              0      SAN AGUSTIN DE LAS JUNTAS
# 44185             117            117               UNIDAD DEL VALLE
# 107775            169            NaN                EMILIANO ZAPATA
# 299035             28           LT21                      TLANALAPA
# ...               ...            ...                            ...
# 120178             SN            NaN                       NOHUAYUN
# 281332             24            NaN  TLACOLULA DE MATAMOROS CENTRO
# 131833          MZA21           LT20             Lomas de Xocomulco
# 12705            ED D          D 102     SAN RAFAEL 1A Y 2A SECCION
# 127901            MZ4            LT9                     TLAPECHICO
#
#                 FC_MUNICIPIOHOGAR    FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS  \
# 296237                       LEON        GUANAJUATO           37510  MEXICO
# 211820  SAN AGUSTIN DE LAS JUNTAS            OAXACA           71238  MEXICO
# 44185                     TAMPICO        TAMAULIPAS           89367  MEXICO
# 107775                TLAQUEPAQUE           JALISCO           45638  Mexico
# 299035                  TLANALAPA           HIDALGO           43930  MEXICO
# ...                           ...               ...             ...     ...
# 120178                    Tahdziú           YUCATAN           97364  MEXICO
# 281332     TLACOLULA DE MATAMOROS            OAXACA           70403  Mexico
# 131833  Chilpancingo de los Bravo          GUERRERO           39036  MEXICO
# 12705     Coacalco de Berriozábal            MEXICO           55719  MEXICO
# 127901             ALVARO OBREGON  DISTRITO FEDERAL           01230  MEXICO
#
#        FI_ID_TIPOVIVIENDA FC_ID_TIPOVIVIENDA           FC_LATITUD  \
# 296237                  3             PROPIA  21.1087050000000000
# 211820                  3             PROPIA  17.0096620000000000
# 44185                   3             PROPIA  22.2849670000000000
# 107775                  2           FAMILIAR  20.5956000000000000
# 299035                  3             PROPIA  19.8157170000000000
# ...                   ...                ...                  ...
# 120178                  3             PROPIA  20.9616970000000000
# 281332                  3             PROPIA  17.0243880000000000
# 131833                  3             PROPIA  17.5585890000000000
# 12705                   3             PROPIA  19.6484740000000000
# 127901                  3             PROPIA  19.3800240000000000
#
#                   FC_LONGITUD FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO  \
# 296237  -101.6499390000000000         NaN           NaN              20
# 211820   -96.7100280000000000         NaN           NaN              83
# 44185    -97.8848970000000000         NaN           NaN              38
# 107775  -103.2697970000000000         NaN           NaN              98
# 299035   -98.6026740000000000         NaN           NaN              72
# ...                       ...         ...           ...             ...
# 120178   -89.9380800000000000         NaN           NaN              73
# 281332   -96.4190790000000000         NaN           NaN             551
# 131833   -99.5108490000000000         NaN           NaN              29
# 12705    -99.0833230000000000         NaN           NaN              20
# 127901   -99.2415900000000000         NaN           NaN               1
#
#        FC_ID_ESTADO FI_ID_PAIS
# 296237           11          1
# 211820           20          1
# 44185            28          1
# 107775           14          1
# 299035           13          1
# ...             ...        ...
# 120178           31          1
# 281332           20          1
# 131833           12          1
# 12705            15          1
# 127901            9          1
#
# [100 rows x 19 columns]

# %%
m_demograficos
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO FI_PAISCU FI_CANALCU FI_SUCURSALCU  \
# 296237              11879     2472450         1          9          5670
# 211820              11126     1950396         1          1           218
# 44185                4673      238986         1          1          7090
# 107775               5383     1065483         1          1          7034
# 299035              11879     2461778         1          1          2392
# ...                   ...         ...       ...        ...           ...
# 120178               5383     1190451         1          1          6095
# 281332               5383     2370562         1          1          2684
# 131833               5383     1307557         1          1          2079
# 12705                4673      177617         1         20          1652
# 127901               4673     1131903         1          1          2435
#
#        FI_FOLIOCU           FC_INSTITUCION                FC_NOMBRECOMPLETO  \
# 296237       4118   CUTSPEI SIN CLASIFICAR      MARGARITA VILLALPANDO GOMEZ
# 211820       3230                TESOFE 11  RICARDO FRANCISCO ROJAS JIMENEZ
# 44185       16570         IMSS PENSIONADOS        J VICENTE OCHOA HERNANDEZ
# 107775     129701  BAZ PORTABILIDAD NOMINA  ANTONIO DE JESUS CORTES BECERRA
# 299035      51112   CUTSPEI SIN CLASIFICAR       ESMERALDA GUTIERREZ MONTER
# ...           ...                      ...                              ...
# 120178      20096  BAZ PORTABILIDAD NOMINA            SANTOS EDGAR POOT PUC
# 281332     126026  BAZ PORTABILIDAD NOMINA        LUIS ARMANDO LOPEZ GARCIA
# 131833      81623  BAZ PORTABILIDAD NOMINA           ADINA RAMIREZ BALTAZAR
# 12705        4245         IMSS PENSIONADOS            EDUARDO BRAVO ALVAREZ
# 127901      75870         IMSS PENSIONADOS         LAURA ELIZALDE HERNANDEZ
#
#          FD_FECHANACIMIENTO FC_PAISNACIMIENTO  ... FC_APELLIDO_PATERNO  \
# 296237  11/01/1950 00:00:00               NaN  ...         VILLALPANDO
# 211820  12/04/1973 00:00:00               NaN  ...               ROJAS
# 44185   02/01/1947 00:00:00            MEXICO  ...               OCHOA
# 107775  07/06/2001 00:00:00               NaN  ...              CORTES
# 299035  12/02/1993 00:00:00               NaN  ...           GUTIERREZ
# ...                     ...               ...  ...                 ...
# 120178  03/03/1993 12:00:00               NaN  ...                POOT
# 281332  01/13/1998 00:00:00               NaN  ...               LOPEZ
# 131833  04/23/1986 00:00:00               NaN  ...             RAMIREZ
# 12705   09/30/1940 00:00:00            MEXICO  ...               BRAVO
# 127901  03/19/1958 12:00:00               NaN  ...            ELIZALDE
#
#        FC_APELLIDO_MATERNO FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO  \
# 296237               GOMEZ          1  12/06/2020 00:00:00                1
# 211820             JIMENEZ          1  11/01/2019 00:00:00                1
# 44185            HERNANDEZ          1  04/27/2007 00:00:00                1
# 107775             BECERRA          1  06/02/2019 12:00:00                1
# 299035              MONTER          1  12/06/2020 00:00:00                1
# ...                    ...        ...                  ...              ...
# 120178                 PUC          1                  NaN                1
# 281332              GARCIA          1  12/05/2020 00:00:00                1
# 131833            BALTAZAR          1                  NaN                1
# 12705              ALVAREZ          1  03/28/2018 00:00:00                1
# 127901           HERNANDEZ          1                  NaN                1
#
#        FNEDONACIMIENTO FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 296237              11             2             7      1            484
# 211820              20             2             7      2            484
# 44185               28             5             7      2            484
# 107775              14             1             7      2            484
# 299035              13             2             7      1            484
# ...                ...           ...           ...    ...            ...
# 120178              31             1             7      2            484
# 281332              20             1             7      2            484
# 131833              12             2             7      1            484
# 12705               15             2             7      2            484
# 127901               9             5             7      1            484
#
# [100 rows x 42 columns]

# %%
m_dispersiones
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO             FC_CUENTA  \
# 296237              11879     2472450  01275670210120900051
# 211820              11126     1950396  01270180210127920948
# 44185                4673      238986  01277090980176376170
# 107775               5383     1065483  01277034300126590160
# 299035              11879     2461778  01272392110120972965
# ...                   ...         ...                   ...
# 120178               5383     1190451  01276095120128509700
# 281332               5383     2370562  01275647270154199432
# 131833               5383     1307557  01279970050130659970
# 12705                4673      177617  01271652130187177355
# 127901               4673     1131903  01272435350127014289
#
#             FD_ULTIMADISPER  FI_TOTALDISPER  FN_SALARIO FC_PERIODICIDADPAGO  \
# 296237  12/09/2021 00:00:00              18     4916.76             SEMANAL
# 211820  12/09/2021 00:00:00              13     3072.11           QUINCENAL
# 44185   11/30/2021 00:00:00               7     5781.23             MENSUAL
# 107775  12/06/2021 00:00:00              21     2429.64           QUINCENAL
# 299035  12/09/2021 00:00:00              18     4884.24             SEMANAL
# ...                     ...             ...         ...                 ...
# 120178  12/10/2021 00:00:00              29     1291.24             SEMANAL
# 281332  11/16/2021 00:00:00               5     4310.00             MENSUAL
# 131833  11/29/2021 00:00:00              20     5094.78           QUINCENAL
# 12705   11/30/2021 00:00:00               7    10478.61             MENSUAL
# 127901  11/30/2021 00:00:00               7     3677.13             MENSUAL
#
#        FI_CAPACIDADPAGO                        FC_PRODUCTO FI_ID_PRODUCTO  \
# 296237              NaN                      NOMINA AZTECA             10
# 211820              NaN                      NOMINA AZTECA             10
# 44185               NaN            PENSIONADOS Y JUBILADOS             11
# 107775              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 299035              NaN                      NOMINA AZTECA             10
# ...                 ...                                ...            ...
# 120178              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 281332              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 131833              NaN  CREDITO DE PORTABILIDAD INMEDIATO              4
# 12705               NaN            PENSIONADOS Y JUBILADOS             11
# 127901              NaN            PENSIONADOS Y JUBILADOS             11
#
#        FI_CREDITOSACTIV  FIPERIODICIDADPAGO FI_CTA_DIGITOS
# 296237                0                   1      120900051
# 211820                0                   2      127920948
# 44185                 0                   3      176376170
# 107775                2                   2      126590160
# 299035                0                   1      120972965
# ...                 ...                 ...            ...
# 120178                0                   1      128509700
# 281332                0                   3      154199432
# 131833                1                   2      130659970
# 12705                 0                   3      187177355
# 127901                0                   3      127014289
#
# [100 rows x 13 columns]

# %%
m_domicilios
# Out:
#        #FI_ID_INSTITUCION FI_EMPLEADO              FC_CALLEHOGAR  \
# 296237              11879     2472450             PRIV LA FUENTE
# 211820              11126     1950396                   RIO SECO
# 44185                4673      238986         AVENIDA CONTADORES
# 107775               5383     1065483                   RIO TULA
# 299035              11879     2461778  PRIV REAL DE SAN FRANCISC
# ...                   ...         ...                        ...
# 120178               5383     1190451                          3
# 281332               5383     2370562                    GALEANA
# 131833               5383     1307557            BAJA CALIFORNIA
# 12705                4673      177617                  MZ L LT 1
# 127901               4673     1131903        2DO CJON TLAPECHICO
#
#        FC_NUMEXTHOGAR FC_NUMINTHOGAR                FC_COLONIAHOGAR  \
# 296237            118            NaN              PARQUE MANZANARES
# 211820              3              0      SAN AGUSTIN DE LAS JUNTAS
# 44185             117            117               UNIDAD DEL VALLE
# 107775            169            NaN                EMILIANO ZAPATA
# 299035             28           LT21                      TLANALAPA
# ...               ...            ...                            ...
# 120178             SN            NaN                       NOHUAYUN
# 281332             24            NaN  TLACOLULA DE MATAMOROS CENTRO
# 131833          MZA21           LT20             Lomas de Xocomulco
# 12705            ED D          D 102     SAN RAFAEL 1A Y 2A SECCION
# 127901            MZ4            LT9                     TLAPECHICO
#
#                 FC_MUNICIPIOHOGAR    FC_ESTADOHOGAR FC_CODIGOPOSTAL FC_PAIS  \
# 296237                       LEON        GUANAJUATO           37510  MEXICO
# 211820  SAN AGUSTIN DE LAS JUNTAS            OAXACA           71238  MEXICO
# 44185                     TAMPICO        TAMAULIPAS           89367  MEXICO
# 107775                TLAQUEPAQUE           JALISCO           45638  Mexico
# 299035                  TLANALAPA           HIDALGO           43930  MEXICO
# ...                           ...               ...             ...     ...
# 120178                    Tahdziú           YUCATAN           97364  MEXICO
# 281332     TLACOLULA DE MATAMOROS            OAXACA           70403  Mexico
# 131833  Chilpancingo de los Bravo          GUERRERO           39036  MEXICO
# 12705     Coacalco de Berriozábal            MEXICO           55719  MEXICO
# 127901             ALVARO OBREGON  DISTRITO FEDERAL           01230  MEXICO
#
#        FI_ID_TIPOVIVIENDA FC_ID_TIPOVIVIENDA           FC_LATITUD  \
# 296237                  3             PROPIA  21.1087050000000000
# 211820                  3             PROPIA  17.0096620000000000
# 44185                   3             PROPIA  22.2849670000000000
# 107775                  2           FAMILIAR  20.5956000000000000
# 299035                  3             PROPIA  19.8157170000000000
# ...                   ...                ...                  ...
# 120178                  3             PROPIA  20.9616970000000000
# 281332                  3             PROPIA  17.0243880000000000
# 131833                  3             PROPIA  17.5585890000000000
# 12705                   3             PROPIA  19.6484740000000000
# 127901                  3             PROPIA  19.3800240000000000
#
#                   FC_LONGITUD FC_SUCURSAL FI_ID_COLONIA FI_ID_MUNICIPIO  \
# 296237  -101.6499390000000000         NaN           NaN              20
# 211820   -96.7100280000000000         NaN           NaN              83
# 44185    -97.8848970000000000         NaN           NaN              38
# 107775  -103.2697970000000000         NaN           NaN              98
# 299035   -98.6026740000000000         NaN           NaN              72
# ...                       ...         ...           ...             ...
# 120178   -89.9380800000000000         NaN           NaN              73
# 281332   -96.4190790000000000         NaN           NaN             551
# 131833   -99.5108490000000000         NaN           NaN              29
# 12705    -99.0833230000000000         NaN           NaN              20
# 127901   -99.2415900000000000         NaN           NaN               1
#
#        FC_ID_ESTADO FI_ID_PAIS
# 296237           11          1
# 211820           20          1
# 44185            28          1
# 107775           14          1
# 299035           13          1
# ...             ...        ...
# 120178           31          1
# 281332           20          1
# 131833           12          1
# 12705            15          1
# 127901            9          1
#
# [100 rows x 19 columns]

# %%
m_domicilios.to_csv('DM_DatosDomicilio.txt', sep='|', index=False)
m_dispersiones.to_csv('DM_DatosDispersion.txt', sep='|', index=False)
m_demograficos.to_csv('DM_DatosGenerales.txt', sep='|', index=False)

# %%
#FI_PAISCU	FI_CANALCU	FI_SUCURSALCU	FI_FOLIOCU
marca_big.rename(columns={'#FI_ID_PAIS_CU':'FI_PAISCU','FI_ID_SUCURSAL_CU':'FI_SUCURSALCU','FI_ID_CANAL_CU':'FI_CANALCU','FI_FOLIO_CU':'FI_FOLIOCU'}, inplace=True)

# %%
marca_big
# Out:
#         FI_PAISCU FI_SUCURSALCU FI_CANALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0              -9         -5644          1       3323                    0
# 1              -1           172         20      24400                    0
# 2               1           100          1         87                   14
# 3               1           100          1        192                    4
# 4               1           100          1        239                   10
# ...           ...           ...        ...        ...                  ...
# 1863768         1          7566          1      65859                    4
# 1863769         1          6023          1      86678                    4
# 1863770         1          5667          1      27704                    4
# 1863771         1          9376          1       2917                    4
# 1863772         1          5572         39      25027                    4
#
#         FI_MARCA
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 1863768        1
# 1863769        1
# 1863770        1
# 1863771        1
# 1863772        1
#
# [1863773 rows x 6 columns]

# %%
marca_big = marca_big[['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU','FI_COD_IDENTIFICADOR','FI_MARCA']]

# %%
marca_big
# Out:
#         FI_PAISCU FI_CANALCU FI_SUCURSALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0              -9          1         -5644       3323                    0
# 1              -1         20           172      24400                    0
# 2               1          1           100         87                   14
# 3               1          1           100        192                    4
# 4               1          1           100        239                   10
# ...           ...        ...           ...        ...                  ...
# 1863768         1          1          7566      65859                    4
# 1863769         1          1          6023      86678                    4
# 1863770         1          1          5667      27704                    4
# 1863771         1          1          9376       2917                    4
# 1863772         1         39          5572      25027                    4
#
#         FI_MARCA
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 1863768        1
# 1863769        1
# 1863770        1
# 1863771        1
# 1863772        1
#
# [1863773 rows x 6 columns]

# %%
marca_big.merge(m_demograficos, on=['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU'])
# Out:
#    FI_PAISCU FI_CANALCU FI_SUCURSALCU FI_FOLIOCU FI_COD_IDENTIFICADOR  \
# 0          1          1           110     134777                    4
# 1          1          1           128      13335                   10
# 2          1          1           151      39284                    4
# 3          1          1           185      39859                   11
# 4          1          1           218       3230                   14
# ..       ...        ...           ...        ...                  ...
# 95         1          1          6113      46928                   11
# 96         1          1          3421       4225                   11
# 97         1          1          2764     121777                   11
# 98         1          1          4941      84915                   11
# 99         1         20          1655       7869                   15
#
#    FI_MARCA #FI_ID_INSTITUCION FI_EMPLEADO            FC_INSTITUCION  \
# 0         1               5383     1870474   BAZ PORTABILIDAD NOMINA
# 1         1              10229     1791279  MUNICIPIO DE GUADALAJARA
# 2         1               5383     1056277   BAZ PORTABILIDAD NOMINA
# 3         1               4673      278771          IMSS PENSIONADOS
# 4         1              11126     1950396                 TESOFE 11
# ..      ...                ...         ...                       ...
# 95        1               4673     2683058          IMSS PENSIONADOS
# 96        1               4673     2685395          IMSS PENSIONADOS
# 97        1               4673     2537164          IMSS PENSIONADOS
# 98        1               4673     2537847          IMSS PENSIONADOS
# 99        1               4673     2536095          IMSS PENSIONADOS
#
#                    FC_NOMBRECOMPLETO  ... FC_APELLIDO_PATERNO  \
# 0           GONZALO NICASIO ESCOBEDO  ...             NICASIO
# 1          HUGO FELIPE MEDINA ORTEGA  ...              MEDINA
# 2   CRISTIAN ANTONIO SILVA CONTRERAS  ...               SILVA
# 3            NICOLAS TINOCO ALVARADO  ...              TINOCO
# 4    RICARDO FRANCISCO ROJAS JIMENEZ  ...               ROJAS
# ..                               ...  ...                 ...
# 95                 PETRA REZA GARCIA  ...                REZA
# 96              RODOLFO CERON VALDEZ  ...               CERON
# 97            ELIZABETH CRUZ MORALES  ...                CRUZ
# 98           SOFIA HERNANDEZ DELGADO  ...           HERNANDEZ
# 99                CELIA MORALES CRUZ  ...             MORALES
#
#    FC_APELLIDO_MATERNO FI_ID_PAIS        FD_FECHA_ALTA FNPAISNACIMIENTO  \
# 0             ESCOBEDO          1  08/14/2020 00:00:00                1
# 1               ORTEGA          1                  NaN                1
# 2            CONTRERAS          1                  NaN                1
# 3             ALVARADO          1  02/22/2016 00:00:00                1
# 4              JIMENEZ          1  11/01/2019 00:00:00                1
# ..                 ...        ...                  ...              ...
# 95              GARCIA          1  12/08/2020 00:00:00                1
# 96              VALDEZ          1  12/08/2020 00:00:00                1
# 97             MORALES          1  12/07/2020 00:00:00                1
# 98             DELGADO          1  12/07/2020 00:00:00                1
# 99                CRUZ          1  12/07/2020 00:00:00                1
#
#    FNEDONACIMIENTO FNESTADOCIVIL FNESCOLARIDAD FNSEXO FNNACIONALIDAD
# 0               28             1             7      2            484
# 1               14             1             7      2            484
# 2               24             1             7      1            484
# 3                9             2             7      2            484
# 4               20             2             7      2            484
# ..             ...           ...           ...    ...            ...
# 95              15             5             7      1            484
# 96              15             2             7      2            484
# 97              14             5             7      1            484
# 98              15             5             7      1            484
# 99              15             1             7      1            484
#
# [100 rows x 44 columns]

# %%
m_marca_big = marca_big.merge(m_demograficos, on=['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU'])

# %%
m_marca_big = m_marca_big[['FI_PAISCU','FI_CANALCU','FI_SUCURSALCU','FI_FOLIOCU','FI_COD_IDENTIFICADOR','FI_MARCA']]

# %%
m_marca_big
# Out:
#    FI_PAISCU FI_CANALCU FI_SUCURSALCU FI_FOLIOCU FI_COD_IDENTIFICADOR FI_MARCA
# 0          1          1           110     134777                    4        1
# 1          1          1           128      13335                   10        1
# 2          1          1           151      39284                    4        1
# 3          1          1           185      39859                   11        1
# 4          1          1           218       3230                   14        1
# ..       ...        ...           ...        ...                  ...      ...
# 95         1          1          6113      46928                   11        1
# 96         1          1          3421       4225                   11        1
# 97         1          1          2764     121777                   11        1
# 98         1          1          4941      84915                   11        1
# 99         1         20          1655       7869                   15        1
#
# [100 rows x 6 columns]

# %%
m_marca_big.to_csv('Marca_BIG.txt', sep='|', index=False)
